# %% [markdown]
# # Otención taxonimía Topicos Constitute Project

# %%
import requests

# %%
url = "https://www.constituteproject.org/service/topics?lang=es"

# A GET request to the API
response = requests.get(url)

# Print the response
response_json = response.json()
print(response_json)
# Out:
# [{'count': 95, 'description': '', 'key': 'amendment', 'keywords': [], 'label': 'Enmienda', 'topics': [{'count': 28, 'description': 'Algunas disposiciones constitucionales pueden ser tan fundamentales o polémicas para el orden constitucional, que se establecen como irreformables. En tales casos, las disposiciones irreformables son expresamente mencionadas en la Constitución.', 'key': 'unamend', 'keywords': ['derogable', 'inalienable', 'inviolable'], 'label': 'Disposiciones constitucionales no sujetas a reforma', 'topics': []}, {'count': 67, 'description': 'Detalla la forma en que el texto de la constitución pude ser modificado formalmente. Esto es distinto a la tarea de interpretación constitucional generalmente realizada por los tribunales.', 'key': 'amend', 'keywords': [], 'label': 'Procedimiento de reforma constitucional', 'topics': []}]}, {'count': 767, 'description': '', 'key': 'culture_and_identity', 'keywords': [], 'label': 'Cultura e Identidad', 'topics': [{'count': 30, 'description': '', 'key': 'Indigenous_Groups', 'keywords': [], 'label': 'Grupos Indígenas', 'topics': [{'count': 0, 'description': 'Otorga a los pueblos indígenas el derecho a participar en actividades que son ilegales para la población no indígena.', 'key': 'indpolgr5', 'keywords': [], 'label': 'Derecho de indígenas a actividades ilegales', 'topics': []}, {'count': 0, 'description': 'Otorga a los pueblos indígenas el derecho a formar partidos políticos sobre la base de la identidad de grupo.', 'key': 'indpolgr3', 'keywords': [], 'label': 'Derechos de indígenas a partidos políticos', 'topics': []}, {'count': 9, 'description': 'Otorga a los pueblos indígenas autonomía limitada, particularmente en lo que respecta a cuestiones que afectan su territorio.', 'key': 'indpolgr6', 'keywords': [], 'label': 'Derechos de los indígenas a auto-gobierno', 'topics': []}, {'count': 2, 'description': 'Otorga a los pueblos indígenas una exención de los impuestos establecidos por el gobierno central.', 'key': 'indpolgr4', 'keywords': [], 'label': 'Derechos de los indígenas a no pagar impuestos', 'topics': []}, {'count': 8, 'description': 'Otorga a los pueblos indígenas el derecho a ser representados en el gobierno central. Esto puede implicar, por ejemplo, una cuota en la legislatura.', 'key': 'indpolgr2', 'keywords': [], 'label': 'Derechos de los indígenas a ser representados', 'topics': []}, {'count': 5, 'description': 'Otorga a los pueblos indígenas el derecho a votar en elecciones o referendos nacionales.', 'key': 'indpolgr1', 'keywords': ['sufragio'], 'label': 'Derechos de los indígenas al voto', 'topics': []}, {'count': 6, 'description': 'Aclara la situación de ciudadanía de los miembros de grupos indígenas. En algunos casos podrá concederse la ciudadanía a grupos indígenas en una unidad sub-nacional.', 'key': 'indcit', 'keywords': [], 'label': 'Nacionalidad de los grupos indígenas', 'topics': []}]}, {'count': 134, 'description': '', 'key': 'Language', 'keywords': [], 'label': 'Idioma', 'topics': [{'count': 20, 'description': 'Otorga a personas acusadas de un delito el derecho a que su juicio sea llevado a cabo en un idioma que comprenda, o el derecho a tener un intérprete. En algunos casos, esto incluirá el derecho a ser informado de las razones de su detención.', 'key': 'trilang', 'keywords': ['acusado', 'procedimiento penal'], 'label': 'Derecho del acusado a ser juzgado en su idioma nativo', 'topics': []}, {'count': 48, 'description': 'Establece los idiomas oficiales del Estado. Los idiomas oficiales son los que se utilizan para la interacción con agencias estatales. Los idiomas nacionales son a menudo los idiomas nativos, mientras que los idiomas oficiales del Estado son generalmente el idioma de una antigua potencia colonial.', 'key': 'lang', 'keywords': [], 'label': 'Idiomas oficiales o nacionales', 'topics': []}, {'count': 29, 'description': 'Requiere que todos sean tratados con igualdad ante la ley, sin distinción de su idioma nativo. Esto puede aplicarse tant ...

# %%
len(response_json)
# Out:
# 12

# %%
for topics in response_json:
    print(topics["label"] + " " + str(topics["count"]))
    for subtopics in topics["topics"]:
        print("\t",subtopics["label"] + " " + str(subtopics["count"]))
        for subsubtopics in subtopics["topics"]:
            print("\t\t",subsubtopics["label"] + " " + str(subsubtopics["count"]))
# Out:
# Enmienda 95
# 	 Disposiciones constitucionales no sujetas a reforma 28
# 	 Procedimiento de reforma constitucional 67
# Cultura e Identidad 767
# 	 Grupos Indígenas 30
# 		 Derecho de indígenas a actividades ilegales 0
# 		 Derechos de indígenas a partidos políticos 0
# 		 Derechos de los indígenas a auto-gobierno 9
# 		 Derechos de los indígenas a no pagar impuestos 2
# 		 Derechos de los indígenas a ser representados 8
# 		 Derechos de los indígenas al voto 5
# 		 Nacionalidad de los grupos indígenas 6
# 	 Idioma 134
# 		 Derecho del acusado a ser juzgado en su idioma nativo 20
# 		 Idiomas oficiales o nacionales 48
# 		 Igualdad sin distinción de idioma 29
# 		 Protección del uso del idioma 37
# 	 Nacionalidad 264
# 		 Condiciones para revocar la ciudadanía 50
# 		 Derecho de renunciar a la ciudadanía 27
# 		 Facultad para deportar a ciudadanos 12
# 		 Igualdad sin distinción de nacionalidad 12
# 		 Igualdad sin distinción de origen 26
# 		 Nacionalidad de los grupos indígenas 6
# 		 Requisitos para nacionalización 51
# 		 Requisitos para obtener nacionalidad por nacimiento 60
# 		 Restricciones de entrada y salida 20
# 	 Raza y Etnicidad 76
# 		 Igualdad sin distinción de raza 37
# 		 Igualdad sin distinción de tribu o clan 2
# 		 Integración de comunidades étnicas 19
# 		 Redistribución de la riqueza 18
# 	 Religión 263
# 		 Dios u otras deidades 44
# 		 Establecimiento de tribunales eclesiásticos 3
# 		 Estatus del derecho canónico (religioso) 7
# 		 Estatus fiscal de organizaciones religiosas 9
# 		 Igualdad sin distinción de fe o creencias 28
# 		 Igualdad sin distinción de religión 42
# 		 Libertad religiosa 67
# 		 Religión oficial 36
# 		 Separación de iglesia y Estado 27
# Elecciones 662
# 	 Normas y Procedimientos Electorales 186
# 		 Censos 25
# 		 Distritos electorales 28
# 		 Financiamiento de campañas 30
# 		 Programación de elecciones 43
# 		 Voto secreto 60
# 	 Partidos Políticos 145
# 		 Derecho a formar partidos políticos 47
# 		 Derechos de indígenas a partidos políticos 0
# 		 Igualdad sin distinción de partido político 19
# 		 Obligación de incorporarse a un partido político 0
# 		 Partidos políticos predilectos/preferidos 4
# 		 Partidos políticos prohibidos 20
# 		 Regulación de partidos políticos 15
# 		 Restricciones a partidos políticos 40
# 	 Referendos e Iniciativas 89
# 		 Iniciativas legislativas ciudadanas 33
# 		 Referéndum 56
# 	 Sufragio y Participación Electoral 123
# 		 Derechos de los indígenas al voto 5
# 		 Restricciones al voto 59
# 		 Sufragio Universal 43
# 		 Voto obligatorio 16
# 	 Supervisión Electoral 119
# 		 Comisión electoral 29
# 		 Duración de un juez del Tribunal Electoral 15
# 		 Edad mínima de los jueces que forman parte del Tribunal Electoral 8
# 		 Facultades del Tribunal Electoral 19
# 		 Límite a los periodos de los jueces en el Tribunal Electoral 3
# 		 Remoción del Tribunal Electoral 9
# 		 Requisitos de los jueces del Tribunal Electoral 17
# 		 Selección de los miembros del Tribunal Electoral 19
# Ejecutivo 2369
# 	 Estructura del Ejecutivo 228
# 		 Nombre/estructura del(os) ejecutivo(s) 67
# 		 Procurador general 53
# 		 Reconocimiento constitucional del gabinete/ministros 67
# 		 Vicepresidente o Vice Primer Ministro 41
# 	 Fuerzas Armadas 374
# 		 Establecimiento de tribunales militares 36
# 		 Facultad de declarar la guerra 52
# 		 Nombramiento del jefe de las fuerzas armadas 63
# 		 Provisiones de emergencia 61
# 		 Restricciones a las fuerzas armadas 43
# 		 Restricciones para ser ministro de defensa 5
# 		 Selección de comandantes en servicio activo 48
# 		 Servicio militar 49
# 		 Terrorismo 17
# 	 Gabinete 311
# 		 Facultades del gabinete 57
# 		 Reconocimiento constitucional del gabinete/ministros 67
# 		 Remoción del gabinete 64
# 		 Requisitos de los miembros del gabinete 58
# 		 Selección del gabinete 65
# 	 Independencia y Facultades del Ejecutivo 643
# 		 Declaración de independencia del ejecutivo 14
# 		 Facultad de decreto del jefe de estado 46
# 		 Facultad de decreto del jefe de gobierno 10
# 		 Facultad de indulto 62
# 		 Facultades del gabinete 57
# 		 Facultades del jefe de estado 63
# 		 Facultades del jefe de gobierno 24
# 		 Inmunidad del jefe de gobierno 11
# 		 Límites para remover al jefe de gobierno 8
# 		 Nombramiento del jefe de las fuerzas armadas 63
# 		 Remoción del gabinete 64
# 		 Remoción del jefe de estado 62
# 		 Remoción del jefe de gobierno 37
# 		 Requisitos de los miembros del gabinete 58
# 		 Supervisión legislativa del ejecutivo 64
# 	 Jefe de Estado 607
# 		 Duración del cargo de Jefe de Estado 59
# 		 Edad mínima del jefe de estado 61
# 		 Facultad de decreto del jefe de estado 46
# 		 Facultades del jefe de estado 63
# 		 Inmunidad del jefe de estado 35
# 		 Límites a los periodos del jefe de estado 51
# 		 Reemplazo del jefe de estado 65
# 		 Remoción del jefe de estado 62
# 		 Requisitos para ser Jefe de Estado 62
# 		 Selección del Jefe de Estado 66
# 		 Órganos consultivos del Jefe de Estado 37
# 	 Jefe de Gobierno 206
# 		 Duración del cargo de Jefe de Gobierno 9
# 		 Edad mínima del jefe de gobierno 12
# 		 Facultad de decreto del jefe de gobierno 10
# 		 Facultades del jefe de gobierno 24
# 		 Inmunidad del jefe de gobierno 11
# 		 Límites a los periodos de jefe de gobierno 5
# 		 Límites para remover al jefe de gobierno 8
# 		 Reemplazo del jefe de gobierno 19
# 		 Remoción del jefe de gobierno 37
# 		 Requisitos para ser Jefe de Gobierno 19
# 		 Rol del jefe de gobierno en la legislatura 15
# 		 Selección del Jefe de Gobierno 37
# Federalismo 186
# 	 Estructura del Estado 112
# 		 Gobierno municipal 60
# 		 Unidad gubernamental subsidiaria 52
# 	 Facultad Legislativa 53
# 		 Legislación nacional vrs. sub-nacional 31
# 		 Revisión federal de legislación sub-nacional 22
# 	 Secesión y Anexión 21
# 		 Anexión de territorio 17
# 		 Secesión de territorio 4
# Normas Internacionales 412
# 	 Política Exterior 112
# 		 Facultad de declarar la guerra 52
# 		 Representante en relaciones exteriores 60
# 	 Referencias Explícitas al Derecho Internacional 161
# 		 Derecho internacional 65
# 		 Derecho internacional consuetudinario 33
# 		 Organizaciones internacionales 44
# 		 Tratados internacionales de derechos humanos 19
# 	 Tratados 139
# 		 Estatus legal de los tratados 54
# 		 Ratificación de tratados 66
# 		 Tratados internacionales de derechos humanos 19
# Judicial 1565
# 	 Autonomía y Facultades del Judicial 388
# 		 Constitucionalidad de legislación 53
# 		 Edad de jubilación forzosa de los jueces 26
# 		 Facultades de la Corte Suprema 41
# 		 Facultades del Tribunal Constitucional 34
# 		 Independencia judicial 60
# 		 Interpretación constitucional 61
# 		 Precedente judicial 11
# 		 Protección del salario de los jueces 26
# 		 Remoción de jueces de la corte Suprema/ordinaria 60
# 		 Remoción de un juez del Tribunal Constitucional 16
# 	 Corte Suprema 261
# 		 Duración de un juez de la Corte Suprema 39
# 		 Edad mínima de los jueces que forman parte de la Corte Suprema 19
# 		 Facultades de la Corte Suprema 41
# 		 Límite a los periodos de los jueces en la Corte Suprema 15
# 		 Number of supreme court judges 28
# 		 Opiniones de la Corte Suprema 15
# 		 Requisitos de los jueces de la Corte Suprema 43
# 		 Selección de los miembros de la Corte Suprema 61
# 	 Estructura del Poder Judicial 225
# 		 Establecimiento de tribunales administrativos 28
# 		 Establecimiento de tribunales de amparo 0
# 		 Establecimiento de tribunales eclesiásticos 3
# 		 Establecimiento de tribunales laborales 9
# 		 Establecimiento de tribunales militares 36
# 		 Establecimiento de tribunales tributarios 0
# 		 Establecimiento de un consejo judicial 39
# 		 Establecimiento del Tribunal Constitucional 35
# 		 Estructura de los tribunales 67
# 		 Tribunales para juzgar a servidores públicos 8
# 	 Revisión Judicial 174
# 		 Acciones administrativas ultra-vires 40
# 		 Constitucionalidad de legislación 53
# 		 Derecho de amparo 20
# 		 Interpretación constitucional 61
# 	 Tribunal Constitucional 211
# 		 Duración de un juez del Tribunal Constitucional 31
# 		 Edad mínima de los jueces que forman parte del Tribunal Constitucional 7
# 		 Establecimiento del Tribunal Constitucional 35
# 		 Facultades del Tribunal Constitucional 34
# 		 Límite a los periodos de los jueces en el Tribunal Constitucional 21
# 		 Opiniones del Tribunal Constitucional 4
# 		 Remoción de un juez del Tribunal Constitucional 16
# 		 Requisitos de los jueces del Tribunal Constitucional 29
# 		 Selección de los miembros del Tribunal Constitucional 34
# 	 Tribunal Electoral 90
# 		 Duración de un juez del Tribunal Electoral 15
# 		 Edad mínima de los jueces que forman parte del Tribunal Electoral 8
# 		 Facultades del Tribunal Electoral 19
# 		 Límite a los periodos de los jueces en el Tribunal Electoral 3
# 		 Remoción del Tribunal Electoral 9
# 		 Requisitos de los jueces del Tribunal Electoral 17
# 		 Selección de los miembros del Tribunal Electoral 19
# 	 Tribunales administrativos 119
# 		 Acciones administrativas ultra-vires 40
# 		 Duración de un juez de un tribunal administrativo 10
# 		 Edad mínima de los jueces que forman parte de tribunales administrativos 4
# 		 Establecimiento de tribunales administrativos 28
# 		 Límite a los periodos de los jueces en tribunales administrativos 6
# 		 Requisitos de los jueces de tribunales administrativos 13
# 		 Selección de los miembros de tribunales administrativos 18
# 	 Tribunales ordinarios 97
# 		 Duración de un juez de un tribunal ordinario 17
# 		 Edad mínima de los jueces que forman parte de los tribunales ordinarios 7
# 		 Límite a los periodos de los jueces en tribunales ordinarios 4
# 		 Requisitos de los jueces de tribunales ordinarios 20
# 		 Selección de los miembros de tribunales ordinarios 49
# Legislativo 2144
# 	 Destitución y Sustitución 188
# 		 Destitución de la legislatura 36
# 		 Destitución de legisladores (de forma individual) 52
# 		 Inmunidad de legisladores 63
# 		 Reemplazo de legisladores 37
# 	 Estructura de las cámaras legislativas 154
# 		 Comisiones legislativas 59
# 		 Comisiones permanente 28
# 		 Estructura de las cámaras legislativas 67
# 	 Independencia y Facultades del Legislativo 297
# 		 Aprobación de legislación general 60
# 		 Destitución de la legislatura 36
# 		 Destitución de legisladores (de forma individual) 52
# 		 Inmunidad de legisladores 63
# 		 Procedimiento de anulación de veto 49
# 		 Reemplazo de legisladores 37
# 	 Legislación 233
# 		 Aprobación de legislación general 60
# 		 División de trabajo entre las Cámaras 35
# 		 Inicio de legislación general 65
# 		 Procedimiento de anulación de veto 49
# 		 Súper-mayoría necesaria para aprobar legislación 24
# 	 Legislación Especial 186
# 		 Leyes orgánicas 16
# 		 Planes económicos 24
# 		 Presupuesto equilibrado 14
# 		 Proyectos legislativos de gasto 16
# 		 Proyectos legislativos financieros 21
# 		 Proyectos legislativos presupuestarios 61
# 		 Proyectos legislativos tributarios 34
# 	 Primera Cámara 420
# 		 Cuotas de representación en la primera cámara 23
# 		 Duración de un representante de la primera cámara 64
# 		 Edad mínima de los representantes de la primera cámara 58
# 		 Líder de la primera cámara 59
# 		 Límite a los periodos de los representantes de la primera cámara 10
# 		 Políticas reservadas para la primera cámara 28
# 		 Requisitos de los representantes de la primera cámara 61
# 		 Selección de los representantes de la primera cámara 66
# 		 Tamaño de la primera cámara 51
# 	 Reglas y Restricciones Legislativas 439
# 		 Asistencia de los legisladores 18
# 		 Duración de sesiones legislativas 40
# 		 Empleos externos de los legisladores 56
# 		 Periodos legislativos extraordinarios 61
# 		 Publicación de deliberaciones 11
# 		 Quórum de sesiones legislativas 49
# 		 Remuneración de los legisladores 40
# 		 Requisito de publicidad de las remuneraciones 20
# 		 Reunión conjunta de cámaras legislativas 29
# 		 Secreto del votos legislativo 8
# 		 Sesiones públicas o privadas 43
# 		 Supervisión legislativa del ejecutivo 64
# 	 Segunda Cámara 227
# 		 Cuotas de representación en la segunda cámara 11
# 		 Duración de un representante de la segunda cámara 31
# 		 Edad mínima de los representantes de la segunda cámara 27
# 		 Líder de la segunda cámara 34
# 		 Límite a los periodos de los representantes de la segunda cámara 7
# 		 Políticas reservadas para la segunda cámara 19
# 		 Requisitos de los representantes de la primera cámara 33
# 		 Selección de los representantes de la segunda cámara 36
# 		 Tamaño de la segunda cámara 29
# Principios y Símbolos 667
# 	 Definición del Estado y Símbolos 145
# 		 Bandera nacional 51
# 		 Capital nacional 44
# 		 Himno nacional 42
# 		 Lema nacional 8
# 	 Principios Básicos 522
# 		 Colonias 7
# 		 Crímenes del régimen previo 5
# 		 Fuente de autoridad constitucional 46
# 		 Grupo(s) regionales 34
# 		 Intelectuales políticos y personajes históricos 12
# 		 Juramentos de obediencia a la constitución 56
# 		 Motivos para redactar la constitución 44
# 		 Propiedad de recursos naturales 49
# 		 Reclutamiento de servidores públicos 29
# 		 Referencia a la fraternidad/solidaridad 43
# 		 Referencia a la historia del país 24
# 		 Referencia al arte 54
# 		 Referencias a la ciencia 56
# 		 Tipo de gobierno concebido 63
# Regulación y Supervisión 464
# 	 Elecciones 134
# 		 Comisión electoral 29
# 		 Duración de un juez del Tribunal Electoral 15
# 		 Edad mínima de los jueces que forman parte del Tribunal Electoral 8
# 		 Facultades del Tribunal Electoral 19
# 		 Límite a los periodos de los jueces en el Tribunal Electoral 3
# 		 Regulación de partidos políticos 15
# 		 Remoción del Tribunal Electoral 9
# 		 Requisitos de los jueces del Tribunal Electoral 17
# 		 Selección de los miembros del Tribunal Electoral 19
# 	 Medios de comunicación 144
# 		 Comisión de telecomunicaciones 14
# 		 Operación estatal de los medios 30
# 		 Radio 35
# 		 Telecomunicaciones 34
# 		 Televisión 31
# 	 Social Issues 14
# 		 Drugs, alcohol, and illegal substances 14
# 	 Órganos Autónomos y Comisiones 172
# 		 Banco central 39
# 		 Comisión anti-corrupción 8
# 		 Comisión de derechos humanos 14
# 		 Comisión de telecomunicaciones 14
# 		 Comisión de verdad y reconciliación 2
# 		 Comisión electoral 29
# 		 Establecimiento de un consejo judicial 39
# 		 Ombudsman 27
# Derechos y Deberes 4192
# 	 Deberes Ciudadanos 110
# 		 Obligación de incorporarse a un partido político 0
# 		 Obligación de pagar impuestos 32
# 		 Obligación de trabajar 29
# 		 Servicio militar 49
# 	 Deberes Generales 64
# 		 Deber de obedecer la constitución 51
# 		 Efecto vinculante de los derechos constitucionales 13
# 	 Derechos Civiles y Políticos 1026
# 		 Derecho a derrocar un gobierno 15
# 		 Derecho a formar una familia 45
# 		 Derecho a la información 42
# 		 Derecho a la libertad académica 50
# 		 Derecho a la objeción de conciencia 15
# 		 Derecho a la privacidad 62
# 		 Derecho a proteger la propia reputación 32
# 		 Derecho al desarrollo de la personalidad 29
# 		 Derecho al matrimonio 30
# 		 Derecho de petición 53
# 		 Derecho de portar armas 6
# 		 Derecho de renunciar a la ciudadanía 27
# 		 Derechos de los deudores 22
# 		 Derechos de los menores de edad 56
# 		 Dignidad humana 55
# 		 Establece la posibilidad de matrimonio civil 13
# 		 Libertad de asociación 61
# 		 Libertad de expresión 63
# 		 Libertad de movimiento 56
# 		 Libertad de opinión/pensamiento/consciencia 58
# 		 Libertad de prensa 63
# 		 Libertad de reunión 63
# 		 Libertad religiosa 67
# 		 Sufragio Universal 43
# 	 Derechos Económicos 312
# 		 Derecho a contar con propiedad 62
# 		 Derecho a escoger una ocupación 44
# 		 Derecho a establecer un negocio 31
# 		 Derecho a un mercado competitivo 34
# 		 Derecho de transferencia de propiedad 33
# 		 Establece propiedad intelectual 44
# 		 Protección contra la expropiación 64
# 	 Derechos Procesales 779
# 		 Derecho a apelar decisiones judiciales 38
# 		 Derecho a examinar evidencia/testigos 16
# 		 Derecho a juicios expeditos 30
# 		 Derecho a juicios públicos 48
# 		 Derecho a libertad durante la duración de un proceso penal 19
# 		 Derecho a un abogado 50
# 		 Derecho a un juicio justo 36
# 		 Derecho de amparo 20
# 		 Derecho del acusado a ser juzgado en su idioma nativo 20
# 		 Garantías de debido proceso 25
# 		 Jurados obligatorios 19
# 		 Presunción de inocencia 49
# 		 Principio de que no hay crimen sin ley 58
# 		 Privilegios para menores de edad en procesos criminales 18
# 		 Procedimiento de extradición 37
# 		 Prohibición de juzgar dos veces por la misma causa 29
# 		 Protección contra confinamiento injustificado 28
# 		 Protección contra detención arbitraria 64
# 		 Protección contra la auto-incriminación 39
# 		 Protección de derechos de las víctimas 21
# 		 Protección frente a leyes ex post facto 55
# 		 Registro público de prisiones 6
# 		 Regulación de recolección de evidencia 54
# 	 Derechos Sociales 895
# 		 Acceso a la educación superior 30
# 		 Apoyo estatal para adultos mayores 49
# 		 Apoyo estatal para desempleados 33
# 		 Apoyo estatal para menores de edad 49
# 		 Apoyo estatal para personas con discapacidades 52
# 		 Derecho a albergue 36
# 		 Derecho a descanso y ocio 39
# 		 Derecho a disfrutar los beneficios de la ciencia 17
# 		 Derecho a huelga 44
# 		 Derecho a igualdad salarial 48
# 		 Derecho a la salud 55
# 		 Derecho a un ambiente laboral seguro 36
# 		 Derecho a un estándar razonable de vida 39
# 		 Derecho al trabajo 52
# 		 Derecho de asociación a sindicatos 55
# 		 Educación gratuita 62
# 		 Educación obligatoria 55
# 		 Límites relativos al empleo de menores de edad 35
# 		 Protección al consumidor 30
# 		 Protección del medio ambiente 60
# 		 Right to water 19
# 	 Derechos a la Integridad Física 247
# 		 Derecho a la vida 52
# 		 Prohibición de castigos corporales 9
# 		 Prohibición de la esclavitud 43
# 		 Prohibición de la pena de muerte 37
# 		 Prohibición de la tortura 54
# 		 Prohibición de tratos crueles 52
# 	 Derechos de Igualdad, Género y Minoría 651
# 		 Derecho a la autodeterminación 21
# 		 Derecho a la cultura 59
# 		 Derecho de indígenas a actividades ilegales 0
# 		 Derechos de indígenas a partidos políticos 0
# 		 Derechos de los indígenas a auto-gobierno 9
# 		 Derechos de los indígenas a no pagar impuestos 2
# 		 Derechos de los indígenas a ser representados 8
# 		 Derechos de los indígenas al voto 5
# 		 Garantía general de igualdad 66
# 		 Igualdad de personas con discapacidades 19
# 		 Igualdad marital 34
# 		 Igualdad sin distinción de color de piel 16
# 		 Igualdad sin distinción de edad 12
# 		 Igualdad sin distinción de estatus financiero 14
# 		 Igualdad sin distinción de estatus social 23
# 		 Igualdad sin distinción de fe o creencias 28
# 		 Igualdad sin distinción de género 55
# 		 Igualdad sin distinción de idioma 29
# 		 Igualdad sin distinción de nacionalidad 12
# 		 Igualdad sin distinción de orientación sexual 9
# 		 Igualdad sin distinción de origen 26
# 		 Igualdad sin distinción de origen familiar 10
# 		 Igualdad sin distinción de partido político 19
# 		 Igualdad sin distinción de raza 37
# 		 Igualdad sin distinción de religión 42
# 		 Igualdad sin distinción de tribu o clan 2
# 		 Menciones a la clase social 34
# 		 Nacionalidad de los grupos indígenas 6
# 		 Protección de personas sin patria 42
# 		 Restricciones a derechos de grupos 12
# 	 Ejecución 108
# 		 Comisión de derechos humanos 14
# 		 Derecho de amparo 20
# 		 Derechos inalienables 47
# 		 Establecimiento de tribunales de amparo 0
# 		 Ombudsman 27
# Secciones Especiales 107
# 	 Disposiciones transitorias 55
# 	 Preámbulo 52

# %%
nombreClases = {}
for topics in response_json:
    for subtopics in topics["topics"]:
        if topics["key"] not in nombreClases:
            nombreClases[topics["key"]] = []
        nombreClases[topics["key"]].append(subtopics["key"])
        for subsubtopics in subtopics["topics"]:
            if subtopics["key"] not in nombreClases:
                nombreClases[subtopics["key"]] = []
            nombreClases[subtopics["key"]].append(subsubtopics["key"])
            nombreClases[topics["key"]].append(subsubtopics["key"])

# %%
prueba = {12 : "hola"}
if "Civil_and_Political_Rights" in nombreClases:
    print(14)
# Out:
# 14

# %%
url = "https://www.constituteproject.org/service/topics?lang=en"

# A GET request to the API
response = requests.get(url)

# Print the response
response_json = response.json()

for topics in response_json:
    print(topics["label"])
    for subtopics in topics["topics"]:
        print("\t",subtopics["label"])
        for subsubtopics in subtopics["topics"]:
            print("\t\t",subsubtopics["label"])
# Out:
# Amendment
# 	 Constitution amendment procedure
# 	 Unamendable provisions
# Culture and Identity
# 	 Citizenship
# 		 Citizenship of indigenous groups
# 		 Conditions for revoking citizenship
# 		 Equality regardless of nationality
# 		 Equality regardless of origin
# 		 Power to deport citizens
# 		 Requirements for birthright citizenship
# 		 Requirements for naturalization
# 		 Restrictions on entry or exit
# 		 Right to renounce citizenship
# 	 Indigenous Groups
# 		 Citizenship of indigenous groups
# 		 Indigenous right not to pay taxes
# 		 Indigenous right to illegal activities
# 		 Indigenous right to political parties
# 		 Indigenous right to representation
# 		 Indigenous right to self governance
# 		 Indigenous right to vote
# 	 Language
# 		 Equality regardless of language
# 		 Official or national languages
# 		 Protection of language use
# 		 Trial in native language of accused
# 	 Race and Ethnicity
# 		 Equality regardless of race
# 		 Equality regardless of tribe or clan
# 		 Integration of ethnic communities
# 		 Provisions for wealth redistribution
# 	 Religion
# 		 Equality regardless of creed or belief
# 		 Equality regardless of religion
# 		 Establishment of religious courts
# 		 Freedom of religion
# 		 God or other deities
# 		 Official religion
# 		 Separation of church and state
# 		 Status of religious law
# 		 Tax status of religious organizations
# Elections
# 	 Electoral Oversight
# 		 Electoral commission
# 		 Electoral court powers
# 		 Electoral court removal
# 		 Electoral court selection
# 		 Electoral court term length
# 		 Electoral court term limits
# 		 Eligibility for electoral court judges
# 		 Minimum age of electoral court judges
# 	 Electoral Rules and Regulations
# 		 Campaign financing
# 		 Census
# 		 Electoral districts
# 		 Scheduling of elections
# 		 Secret ballot
# 	 Political Parties
# 		 Duty to join a political party
# 		 Equality regardless of political party
# 		 Indigenous right to political parties
# 		 Preferred political parties
# 		 Prohibited political parties
# 		 Regulation of political parties
# 		 Restrictions on political parties
# 		 Right to form political parties
# 	 Referenda and Initiatives
# 		 Legislative initiatives by citizens
# 		 Referenda
# 	 Suffrage and Turnout
# 		 Claim of universal suffrage
# 		 Compulsory voting
# 		 Indigenous right to vote
# 		 Restrictions on voting
# Executive
# 	 Cabinet
# 		 Cabinet removal
# 		 Cabinet selection
# 		 Eligibility for cabinet
# 		 Establishment of cabinet/ministers
# 		 Powers of cabinet
# 	 Executive Independence and Power
# 		 Cabinet removal
# 		 Claim of executive independence
# 		 Designation of commander in chief
# 		 Eligibility for cabinet
# 		 Head of government decree power
# 		 Head of government immunity
# 		 Head of government powers
# 		 Head of government removal
# 		 Head of state decree power
# 		 Head of state powers
# 		 Head of state removal
# 		 Legislative oversight of the executive
# 		 Limits on removing head of government
# 		 Power to pardon
# 		 Powers of cabinet
# 	 Head of Government
# 		 Eligibility for head of government
# 		 Head of government decree power
# 		 Head of government immunity
# 		 Head of government powers
# 		 Head of government removal
# 		 Head of government replacement
# 		 Head of government selection
# 		 Head of government term length
# 		 Head of government term limits
# 		 Head of government's role in the legislature
# 		 Limits on removing head of government
# 		 Minimum age of head of government
# 	 Head of State
# 		 Advisory bodies to the head of state
# 		 Eligibility for head of state
# 		 Head of state decree power
# 		 Head of state immunity
# 		 Head of state powers
# 		 Head of state removal
# 		 Head of state replacement
# 		 Head of state selection
# 		 Head of state term length
# 		 Head of state term limits
# 		 Minimum age of head of state
# 	 Military
# 		 Designation of commander in chief
# 		 Duty to serve in the military
# 		 Emergency provisions
# 		 Establishment of military courts
# 		 Power to declare/approve war
# 		 Restrictions on minister of defense
# 		 Restrictions on the armed forces
# 		 Selection of active-duty commanders
# 		 Terrorism
# 	 Structure of the Executive
# 		 Attorney general
# 		 Deputy executive
# 		 Establishment of cabinet/ministers
# 		 Name/structure of executive(s)
# Federalism
# 	 Lawmaking Power
# 		 Federal review of subnational legislation
# 		 National vs subnational laws
# 	 Secession and Accession
# 		 Accession of territory
# 		 Secession of territory
# 	 Structure of the State
# 		 Municipal government
# 		 Subsidiary unit government
# International Law
# 	 Explicit References to Int. Law
# 		 Customary international law
# 		 International human rights treaties
# 		 International law
# 		 International organizations
# 	 Foreign Policy
# 		 Foreign affairs representative
# 		 Power to declare/approve war
# 	 Treaties
# 		 International human rights treaties
# 		 Legal status of treaties
# 		 Treaty ratification
# Judiciary
# 	 Administrative Courts
# 		 Administrative court selection
# 		 Administrative court term length
# 		 Administrative court term limits
# 		 Eligibility for administrative  judges
# 		 Establishment of administrative courts
# 		 Min age of administrative judges
# 		 Ultra-vires administrative actions
# 	 Constitutional Court
# 		 Constitutional court opinions
# 		 Constitutional court powers
# 		 Constitutional court removal
# 		 Constitutional court selection
# 		 Constitutional court term length
# 		 Constitutional court term limits
# 		 Eligibility for const court judges
# 		 Establishment of constitutional court
# 		 Min age of const court judges
# 	 Electoral Courts
# 		 Electoral court powers
# 		 Electoral court removal
# 		 Electoral court selection
# 		 Electoral court term length
# 		 Electoral court term limits
# 		 Eligibility for electoral court judges
# 		 Minimum age of electoral court judges
# 	 Judicial Autonomy and Power
# 		 Constitutional court powers
# 		 Constitutional court removal
# 		 Constitutional interpretation
# 		 Constitutionality of legislation
# 		 Judicial independence
# 		 Judicial precedence
# 		 Mandatory retirement age for judges
# 		 Protection of judges' salaries
# 		 Supreme court powers
# 		 Supreme/ordinary court judge removal
# 	 Judicial Review
# 		 Constitutional interpretation
# 		 Constitutionality of legislation
# 		 Right to amparo
# 		 Ultra-vires administrative actions
# 	 Ordinary Courts
# 		 Eligibility for ordinary court judges
# 		 Minimum age of ordinary court judges
# 		 Ordinary court selection
# 		 Ordinary court term length
# 		 Ordinary court term limits
# 	 Structure of the Judiciary
# 		 Courts for judging public officials
# 		 Establishment of administrative courts
# 		 Establishment of constitutional court
# 		 Establishment of courts of amparo
# 		 Establishment of judicial council
# 		 Establishment of labor courts
# 		 Establishment of military courts
# 		 Establishment of religious courts
# 		 Establishment of tax courts
# 		 Structure of the courts
# 	 Supreme Court
# 		 Eligibility for supreme court judges
# 		 Minimum age of supreme court judges
# 		 Number of supreme court judges
# 		 Supreme court opinions
# 		 Supreme court powers
# 		 Supreme court selection
# 		 Supreme court term length
# 		 Supreme court term limits
# Legislature
# 	 First Chamber
# 		 Eligibility for first chamber
# 		 First chamber representation quotas
# 		 First chamber reserved policy areas
# 		 First chamber selection
# 		 Leader of first chamber
# 		 Minimum age for first chamber
# 		 Size of first chamber
# 		 Term length for first chamber
# 		 Term limits for first chamber
# 	 Legislation
# 		 Approval or veto of general legislation
# 		 Division of labor between chambers
# 		 Initiation of general legislation
# 		 Supermajority required for legislation
# 		 Veto override procedure
# 	 Legislative Independence and Power
# 		 Approval or veto of general legislation
# 		 Dismissal of the legislature
# 		 Immunity of legislators
# 		 Removal of individual legislators
# 		 Replacement of legislators
# 		 Veto override procedure
# 	 Legislative Rules and Restrictions
# 		 Attendance by legislators
# 		 Compensation of legislators
# 		 Earnings disclosure requirement
# 		 Extraordinary legislative sessions
# 		 Joint meetings of legislative chambers
# 		 Legislative oversight of the executive
# 		 Length of legislative sessions
# 		 Outside professions of legislators
# 		 Public or private sessions
# 		 Publication of deliberations
# 		 Quorum for legislative sessions
# 		 Secrecy of legislative votes
# 	 Removal and Replacement
# 		 Dismissal of the legislature
# 		 Immunity of legislators
# 		 Removal of individual legislators
# 		 Replacement of legislators
# 	 Second Chamber
# 		 Eligibility for second chamber
# 		 Leader of second chamber
# 		 Minimum age for second chamber
# 		 Second chamber representation quotas
# 		 Second chamber reserved policy areas
# 		 Second chamber selection
# 		 Size of second chamber
# 		 Term length of second chamber
# 		 Term limits of second chamber
# 	 Special Legislation
# 		 Balanced budget
# 		 Budget bills
# 		 Economic plans
# 		 Finance bills
# 		 Organic laws
# 		 Spending bills
# 		 Tax bills
# 	 Structure of the Legislature
# 		 Legislative committees
# 		 Standing committees
# 		 Structure of legislative chamber(s)
# Principles and Symbols
# 	 Basic Principles
# 		 Civil service recruitment
# 		 Colonies
# 		 Crimes of the previous regime
# 		 Motives for writing constitution
# 		 Oaths to abide by constitution
# 		 Ownership of natural resources
# 		 Political theorists/figures
# 		 Reference to art
# 		 Reference to country's history
# 		 Reference to fraternity/solidarity
# 		 Reference to science
# 		 Regional group(s)
# 		 Source of constitutional authority
# 		 Type of government envisioned
# 	 State Definition and Symbols
# 		 National anthem
# 		 National capital
# 		 National flag
# 		 National motto
# Regulation and Oversight
# 	 Elections
# 		 Electoral commission
# 		 Electoral court powers
# 		 Electoral court removal
# 		 Electoral court selection
# 		 Electoral court term length
# 		 Electoral court term limits
# 		 Eligibility for electoral court judges
# 		 Minimum age of electoral court judges
# 		 Regulation of political parties
# 	 Independent Agencies and Commissions
# 		 Central bank
# 		 Counter corruption commission
# 		 Electoral commission
# 		 Establishment of judicial council
# 		 Human rights commission
# 		 Media commission
# 		 Ombudsman
# 		 Truth and reconciliation commission
# 	 Media and Communications
# 		 Media commission
# 		 Radio
# 		 State operation of the media
# 		 Telecommunications
# 		 Television
# 	 Social Issues
# 		 Drugs, alcohol, and illegal substances
# Rights and Duties
# 	 Citizen Duties
# 		 Duty to join a political party
# 		 Duty to pay taxes
# 		 Duty to serve in the military
# 		 Duty to work
# 	 Civil and Political Rights
# 		 Claim of universal suffrage
# 		 Freedom of assembly
# 		 Freedom of association
# 		 Freedom of expression
# 		 Freedom of movement
# 		 Freedom of opinion/thought/conscience
# 		 Freedom of press
# 		 Freedom of religion
# 		 Human dignity
# 		 Provision for civil marriage
# 		 Regulation of marriage
# 		 Right of petition
# 		 Right to academic freedom
# 		 Right to bear arms
# 		 Right to conscientious objection
# 		 Right to development of personality
# 		 Right to found a family
# 		 Right to information
# 		 Right to overthrow government
# 		 Right to privacy
# 		 Right to protect one's reputation
# 		 Right to renounce citizenship
# 		 Rights of children
# 		 Rights of debtors
# 	 Economic Rights
# 		 Protection from expropriation
# 		 Provisions for intellectual property
# 		 Right to choose occupation
# 		 Right to competitive marketplace
# 		 Right to establish a business
# 		 Right to own property
# 		 Right to transfer property
# 	 Enforcement
# 		 Establishment of courts of amparo
# 		 Human rights commission
# 		 Inalienable rights
# 		 Ombudsman
# 		 Right to amparo
# 	 Equality, Gender, and Minority Rights
# 		 Citizenship of indigenous groups
# 		 Equality for persons with disabilities
# 		 Equality regardless of age
# 		 Equality regardless of creed or belief
# 		 Equality regardless of financial status
# 		 Equality regardless of gender
# 		 Equality regardless of language
# 		 Equality regardless of nationality
# 		 Equality regardless of origin
# 		 Equality regardless of parentage
# 		 Equality regardless of political party
# 		 Equality regardless of race
# 		 Equality regardless of religion
# 		 Equality regardless of sexual orientation
# 		 Equality regardless of skin color
# 		 Equality regardless of social status
# 		 Equality regardless of tribe or clan
# 		 General guarantee of equality
# 		 Indigenous right not to pay taxes
# 		 Indigenous right to illegal activities
# 		 Indigenous right to political parties
# 		 Indigenous right to representation
# 		 Indigenous right to self governance
# 		 Indigenous right to vote
# 		 Mentions of social class
# 		 Protection of stateless persons
# 		 Provision for matrimonial equality
# 		 Restrictions on rights of groups
# 		 Right to culture
# 		 Right to self determination
# 	 General Duties
# 		 Binding effect of const rights
# 		 Duty to obey the constitution
# 	 Legal Procedural Rights
# 		 Extradition procedure
# 		 Guarantee of due process
# 		 Jury trials required
# 		 Presumption of innocence in trials
# 		 Principle of no punishment without law
# 		 Prison registry
# 		 Privileges for juveniles in criminal process
# 		 Prohibition of double jeopardy
# 		 Protection from ex post facto laws
# 		 Protection from false imprisonment
# 		 Protection from self-incrimination
# 		 Protection from unjustified restraint
# 		 Protection of victim's rights
# 		 Regulation of evidence collection
# 		 Right to amparo
# 		 Right to appeal judicial decisions
# 		 Right to counsel
# 		 Right to examine evidence/witnesses
# 		 Right to fair trial
# 		 Right to pre-trial release
# 		 Right to public trial
# 		 Right to speedy trial
# 		 Trial in native language of accused
# 	 Physical Integrity Rights
# 		 Prohibition of capital punishment
# 		 Prohibition of corporal punishment
# 		 Prohibition of cruel treatment
# 		 Prohibition of slavery
# 		 Prohibition of torture
# 		 Right to life
# 	 Social Rights
# 		 Access to higher education
# 		 Compulsory education
# 		 Free education
# 		 Limits on employment of children
# 		 Protection of consumers
# 		 Protection of environment
# 		 Right to enjoy the benefits of science
# 		 Right to health care
# 		 Right to join trade unions
# 		 Right to just remuneration
# 		 Right to reasonable standard of living
# 		 Right to rest and leisure
# 		 Right to safe work environment
# 		 Right to shelter
# 		 Right to strike
# 		 Right to water
# 		 Right to work
# 		 State support for children
# 		 State support for the disabled
# 		 State support for the elderly
# 		 State support for the unemployed
# Special Sections
# 	 Preamble
# 	 Transitional provisions

# %% [markdown]
# # Extracción datos de archivo countries.xml

# %%
formato = "{0} {1} {2}.\n"

print(formato.format("sujeto", "predicado", "objeto"))
# Out:
# sujeto predicado objeto.

# %%
countries = open("CCP_data/ccpcnc_v4/countries.xml", "r")
classes = set()

for i in countries:
    if "rdf:type" in i:
        classes.add(i)
countries.close()

# %%
classes
# Out:
# {'    <rdf:type rdf:resource="http://www.constituteproject.org/ontology/disputed"/>\n',
#  '    <rdf:type rdf:resource="http://www.constituteproject.org/ontology/geographical_region"/>\n',
#  '    <rdf:type rdf:resource="http://www.constituteproject.org/ontology/other"/>\n',
#  '    <rdf:type rdf:resource="http://www.constituteproject.org/ontology/self_governing"/>\n'}

# %%
clases = {
    "type": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>",
    "hasBorderWith": "<http://www.constituteproject.org/ontology/hasBorderWith>",
    "isInGroup": "<http://www.constituteproject.org/ontology/isInGroup>",
    "nameListEN": "<http://www.constituteproject.org/ontology/nameListEN>",
    "nameListES": "<http://www.constituteproject.org/ontology/nameListES>",
    "nameShortEN" : "<http://www.constituteproject.org/ontology/nameShortEN>",
    "nameShortES" : "<http://www.constituteproject.org/ontology/nameShortES>",
    "nameOfficialEN": "<http://www.constituteproject.org/ontology/nameOfficialEN>",
    "nameOfficialES": "<http://www.constituteproject.org/ontology/nameOfficialES>",
    "codeISO3": "<http://www.constituteproject.org/ontology/codeISO3>",
    "codeUN": "<http://www.constituteproject.org/ontology/codeUN>"
         }

# %%
countriesTtl = open("Ttl/countries.ttl", "w")

countries = countries = open("CCP_data/ccpcnc_v4/countries.xml", "r")
sujeto = ""

for country in countries:
    if "<NamedIndividual" in country:
        sujeto = "<" + country[30:-3] + ">"
        #print(sujeto)
        
    elif "<rdf:type" in country:
        objeto = "<" + country[28:-4] + ">"
        countriesTtl.write(formato.format(sujeto, clases["type"],objeto))
    
    elif "<hasBorderWith" in country:
        objeto = "<" + country[33:-4] + ">"
        countriesTtl.write(formato.format(sujeto, clases["hasBorderWith"],objeto))
        
    elif "<isInGroup" in country:
        objeto = "<" + country[29:-4] + ">"
        countriesTtl.write(formato.format(sujeto, clases["isInGroup"],objeto))
        
    elif "<nameListES" in country:
        objeto = country[16:-14]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameListES"],'"' + objeto + '"'))
        
    elif "<nameListEN" in country:
        objeto = country[16:-14]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameListEN"],'"' + objeto + '"'))
        
    elif "<nameOfficialEN" in country:
        objeto = country[20:-18]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameOfficialEN"],'"' + objeto + '"'))
    
    elif "<nameOfficialES" in country:
        objeto = country[20:-18]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameOfficialES"],'"' + objeto + '"'))
        
    elif "<nameShortEN" in country:
        objeto = country[17:-15]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameShortEN"],'"' + objeto + '"'))
        
    elif "<nameShortES" in country:
        objeto = country[17:-15]
        if "xml:lang" in objeto:
            objeto = objeto[14:]
        if "rdf:datatype" in objeto:
            objeto = objeto[55:]
        countriesTtl.write(formato.format(sujeto, clases["nameShortES"],'"' + objeto + '"'))
        
    elif "<codeISO3" in country:
        objeto = country[69:-12]
        countriesTtl.write(formato.format(sujeto, clases["codeISO3"],'"' + objeto + '"'))
        
    elif "<codeUN " in country:
        objeto = country[67:-10]
        countriesTtl.write(formato.format(sujeto, clases["codeUN"],'"' + objeto + '"'))

countries.close()
countriesTtl.close()

# %% [markdown]
# # Extracción de Eventos (OLD)

# %%
clasesEventos = {
    "type": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>",
    "event": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event>",
    "eventId": "<http://www.constituteproject.org/constitution/id>",
    "country": "<http://www.constituteproject.org/constitution/country>",
    "eventType": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event_type>",
    "eventYear": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event_year>",
    "isConstitutionOf" : "<http://www.constituteproject.org/constitution/isConstitutionOf>"
    }

# %%
import re

about = re.compile('rdf:about="http:.*" ')
eventId = re.compile('id="\d*"')
country = re.compile('country=".*"')

prefijo = "<http://www.constituteproject.org/ontology/"

# %%
eventosTtl = open("Ttl/eventos.ttl", "w")
eventos = open("CCP_data/ccpcnc_v4/chronology.xml", "r")

dictEventos = {}

for evento in eventos:
    match = about.search(evento)
    if match != None:
        sujeto = "<" + match.group()[11:-2] + ">"
        eventosTtl.write(formato.format(sujeto, clasesEventos["type"], clasesEventos["event"]))
        
    match = eventId.search(evento)
    if match != None:
        objeto = match.group()[3:]
        eventosTtl.write(formato.format(sujeto,clasesEventos["eventId"] , objeto))
        
        dictEventos[match.group()[4:-1]] = sujeto
        
    match = country.search(evento)
    if match != None:
        objeto = match.group()[8:]
        eventosTtl.write(formato.format(sujeto, clasesEventos["country"], objeto))
        
        objeto = prefijo + objeto[1:-1] + ">"
        eventosTtl.write(formato.format(sujeto, clasesEventos["isConstitutionOf"], objeto))
        
    elif "<event_type" in evento:
        objeto = '"' + evento[16:-14] + '"'
        eventosTtl.write(formato.format(sujeto, clasesEventos["eventType"], objeto))
    
    elif "<event_year" in evento:
        objeto = '"' + evento[16:-14] + '"'
        eventosTtl.write(formato.format(sujeto, clasesEventos["eventYear"], objeto))
    
    


eventosTtl.close()
eventos.close()

# %%
dictEventos
# Out:
# {'3799': '<http://www.constituteproject.org/constitution/Abkhazia_1994>',
#  '1': '<http://www.constituteproject.org/constitution/Afghanistan_1923>',
#  '1934': '<http://www.constituteproject.org/constitution/Afghanistan_1925>',
#  '1935': '<http://www.constituteproject.org/constitution/Afghanistan_1928>',
#  '1936': '<http://www.constituteproject.org/constitution/Afghanistan_1929>',
#  '2': '<http://www.constituteproject.org/constitution/Afghanistan_1931>',
#  '1266': '<http://www.constituteproject.org/constitution/Afghanistan_1933>',
#  '3': '<http://www.constituteproject.org/constitution/Afghanistan_1964>',
#  '1937': '<http://www.constituteproject.org/constitution/Afghanistan_1973>',
#  '4': '<http://www.constituteproject.org/constitution/Afghanistan_1977>',
#  '1938': '<http://www.constituteproject.org/constitution/Afghanistan_1978>',
#  '1267': '<http://www.constituteproject.org/constitution/Afghanistan_1979>',
#  '1268': '<http://www.constituteproject.org/constitution/Afghanistan_1980>',
#  '5': '<http://www.constituteproject.org/constitution/Afghanistan_1987>',
#  '6': '<http://www.constituteproject.org/constitution/Afghanistan_1990>',
#  '1269': '<http://www.constituteproject.org/constitution/Afghanistan_2001>',
#  '7': '<http://www.constituteproject.org/constitution/Afghanistan_2004>',
#  '8': '<http://www.constituteproject.org/constitution/Albania_1914>',
#  '1940': '<http://www.constituteproject.org/constitution/Albania_1920>',
#  '3262': '<http://www.constituteproject.org/constitution/Albania_1922>',
#  '1917': '<http://www.constituteproject.org/constitution/Albania_1925>',
#  '9': '<http://www.constituteproject.org/constitution/Albania_1928>',
#  '3263': '<http://www.constituteproject.org/constitution/Albania_1933>',
#  '1920': '<http://www.constituteproject.org/constitution/Albania_1939>',
#  '1941': '<http://www.constituteproject.org/constitution/Albania_1943>',
#  '10': '<http://www.constituteproject.org/constitution/Albania_1946>',
#  '11': '<http://www.constituteproject.org/constitution/Albania_1950>',
#  '12': '<http://www.constituteproject.org/constitution/Albania_1953>',
#  '13': '<http://www.constituteproject.org/constitution/Albania_1954>',
#  '1942': '<http://www.constituteproject.org/constitution/Albania_1955>',
#  '14': '<http://www.constituteproject.org/constitution/Albania_1958>',
#  '15': '<http://www.constituteproject.org/constitution/Albania_1976>',
#  '1943': '<http://www.constituteproject.org/constitution/Albania_1983>',
#  '16': '<http://www.constituteproject.org/constitution/Albania_1991>',
#  '1271': '<http://www.constituteproject.org/constitution/Albania_1992>',
#  '1272': '<http://www.constituteproject.org/constitution/Albania_1993>',
#  '17': '<http://www.constituteproject.org/constitution/Albania_1998>',
#  '4113': '<http://www.constituteproject.org/constitution/Albania_2007>',
#  '3734': '<http://www.constituteproject.org/constitution/Albania_2008>',
#  '4114': '<http://www.constituteproject.org/constitution/Albania_2012>',
#  '10019': '<http://www.constituteproject.org/constitution/Albania_2015>',
#  '10020': '<http://www.constituteproject.org/constitution/Albania_2016>',
#  '10285': '<http://www.constituteproject.org/constitution/Albania_2020>',
#  '18': '<http://www.constituteproject.org/constitution/Algeria_1963>',
#  '4180': '<http://www.constituteproject.org/constitution/Algeria_1965>',
#  '19': '<http://www.constituteproject.org/constitution/Algeria_1976>',
#  '4183': '<http://www.constituteproject.org/constitution/Algeria_1979>',
#  '4184': '<http://www.constituteproject.org/constitution/Algeria_1980>',
#  '4181': '<http://www.constituteproject.org/constitution/Algeria_1986>',
#  '1944': '<http://www.constituteproject.org/constitution/Algeria_1988>',
#  '20': '<http://www.constituteproject.org/constitution/Algeria_1989>',
#  '4182': '<http://www.constituteproject.org/constitution/Algeria_1992>',
#  '21': '<http://www.constituteproject.org/constitution/Algeria_1996>',
#  '22': '<http://www.constituteproject.org/constitution/Algeria_2002>',
#  '3735': '<http://www.constituteproject.org/constitution/Algeria_2008>',
#  '10015': '<http://www.constituteproject.org/constitution/Algeria_2016>',
#  '10266': '<http://www.constituteproject.org/constitution/Algeria_2020>',
#  '23': '<http://www.constituteproject.org/constitution/Andorra_1993>',
#  '24': '<http://www.constituteproject.org/constitution/Angola_1975>',
#  '1945': '<http://www.constituteproject.org/constitution/Angola_1978>',
#  '25': '<http://www.constituteproject.org/constitution/Angola_1980>',
#  '1946': '<http://www.constituteproject.org/constitution/Angola_1991>',
#  '26': '<http://www.constituteproject.org/constitution/Angola_1992>',
#  '3760': '<http://www.constituteproject.org/constitution/Angola_2010>',
#  '27': '<http://www.constituteproject.org/constitution/Antigua_and_Barbuda_1981>',
#  '3188': '<http://www.constituteproject.org/constitution/Argentina_1811>',
#  '3189': '<http://www.constituteproject.org/constitution/Argentina_1815>',
#  '1947': '<http://www.constituteproject.org/constitution/Argentina_1816>',
#  '3717': '<http://www.constituteproject.org/constitution/Argentina_1817>',
#  '32': '<http://www.constituteproject.org/constitution/Argentina_1819>',
#  '33': '<http://www.constituteproject.org/constitution/Argentina_1826>',
#  '35': '<http://www.constituteproject.org/constitution/Argentina_1853>',
#  '1145': '<http://www.constituteproject.org/constitution/Argentina_1860>',
#  '1146': '<http://www.constituteproject.org/constitution/Argentina_1866>',
#  '1948': '<http://www.constituteproject.org/constitution/Argentina_1880>',
#  '1147': '<http://www.constituteproject.org/constitution/Argentina_1898>',
#  '36': '<http://www.constituteproject.org/constitution/Argentina_1949>',
#  '37': '<http://www.constituteproject.org/constitution/Argentina_1956>',
#  '1278': '<http://www.constituteproject.org/constitution/Argentina_1957>',
#  '1949': '<http://www.constituteproject.org/constitution/Argentina_1966>',
#  '3718': '<http://www.constituteproject.org/constitution/Argentina_1970>',
#  '3710': '<http://www.constituteproject.org/constitution/Argentina_1971>',
#  '1279': '<http://www.constituteproject.org/constitution/Argentina_1972>',
#  '3711': '<http://www.constituteproject.org/constitution/Argentina_1976>',
#  '1950': '<http://www.constituteproject.org/constitution/Argentina_1978>',
#  '3712': '<http://www.constituteproject.org/constitution/Argentina_1979>',
#  '3713': '<http://www.constituteproject.org/constitution/Argentina_1982>',
#  '3714': '<http://www.constituteproject.org/constitution/Argentina_1983>',
#  '38': '<http://www.constituteproject.org/constitution/Argentina_1994>',
#  '3292': '<http://www.constituteproject.org/constitution/Armenia_1863>',
#  '3293': '<http://www.constituteproject.org/constitution/Armenia_1922>',
#  '3294': '<http://www.constituteproject.org/constitution/Armenia_1936>',
#  '3295': '<http://www.constituteproject.org/constitution/Armenia_1978>',
#  '3296': '<http://www.constituteproject.org/constitution/Armenia_1990>',
#  '1952': '<http://www.constituteproject.org/constitution/Armenia_1991>',
#  '43': '<http://www.constituteproject.org/constitution/Armenia_1995>',
#  '1953': '<http://www.constituteproject.org/constitution/Armenia_2005>',
#  '10023': '<http://www.constituteproject.org/constitution/Armenia_2015>',
#  '10286': '<http://www.constituteproject.org/constitution/Armenia_2020>',
#  '1954': '<http://www.constituteproject.org/constitution/Australia_1901>',
#  '45': '<http://www.constituteproject.org/constitution/Australia_1907>',
#  '46': '<http://www.constituteproject.org/constitution/Australia_1910>',
#  '47': '<http://www.constituteproject.org/constitution/Australia_1929>',
#  '3808': '<http://www.constituteproject.org/constitution/Australia_1942>',
#  '48': '<http://www.constituteproject.org/constitution/Australia_1946>',
#  '1282': '<http://www.constituteproject.org/constitution/Australia_1967>',
#  '49': '<http://www.constituteproject.org/constitution/Australia_1977>',
#  '3809': '<http://www.constituteproject.org/constitution/Australia_1985>',
#  '53': '<http://www.constituteproject.org/constitution/Austria_1920>',
#  '1958': '<http://www.constituteproject.org/constitution/Austria_1925>',
#  '3253': '<http://www.constituteproject.org/constitution/Austria_1926>',
#  '3254': '<http://www.constituteproject.org/constitution/Austria_1928>',
#  '54': '<http://www.constituteproject.org/constitution/Austria_1929>',
#  '3255': '<http://www.constituteproject.org/constitution/Austria_1931>',
#  '3256': '<http://www.constituteproject.org/constitution/Austria_1932>',
#  '55': '<http://www.constituteproject.org/constitution/Austria_1934>',
#  '56': '<http://www.constituteproject.org/constitution/Austria_1945>',
#  '1959': '<http://www.constituteproject.org/constitution/Austria_1946>',
#  '1960': '<http://www.constituteproject.org/constitution/Austria_1948>',
#  '1961': '<http://www.constituteproject.org/constitution/Austria_1954>',
#  '57': '<http://www.constituteproject.org/constitution/Austria_1955>',
#  '1962': '<http://www.constituteproject.org/constitution/Austria_1956>',
#  '1963': '<http://www.constituteproject.org/constitution/Austria_1958>',
#  '1964': '<http://www.constituteproject.org/constitution/Austria_1959>',
#  '1965': '<http://www.constituteproject.org/constitution/Austria_1960>',
#  '1966': '<http://www.constituteproject.org/constitution/Austria_1961>',
#  '1967': '<http://www.constituteproject.org/constitution/Austria_1962>',
#  '1968': '<http://www.constituteproject.org/constitution/Austria_1963>',
#  '58': '<http://www.constituteproject.org/constitution/Austria_1964>',
#  '1969': '<http://www.constituteproject.org/constitution/Austria_1968>',
#  '1970': '<http://www.constituteproject.org/constitution/Austria_1969>',
#  '1971': '<http://www.constituteproject.org/constitution/Austria_1972>',
#  '1972': '<http://www.constituteproject.org/constitution/Austria_1973>',
#  '1289': '<http://www.constituteproject.org/constitution/Austria_1974>',
#  '1973': '<http://www.constituteproject.org/constitution/Austria_1975>',
#  '1974': '<http://www.constituteproject.org/constitution/Austria_1977>',
#  '1975': '<http://www.constituteproject.org/constitution/Austria_1979>',
#  '1290': '<http://www.constituteproject.org/constitution/Austria_1981>',
#  '1976': '<http://www.constituteproject.org/constitution/Austria_1982>',
#  '1977': '<http://www.constituteproject.org/constitution/Austria_1983>',
#  '1978': '<http://www.constituteproject.org/constitution/Austria_1984>',
#  '1979': '<http://www.constituteproject.org/constitution/Austria_1986>',
#  '1980': '<http://www.constituteproject.org/constitution/Austria_1987>',
#  '1291': '<http://www.constituteproject.org/constitution/Austria_1988>',
#  '1981': '<http://www.constituteproject.org/constitution/Austria_1990>',
#  '1982': '<http://www.constituteproject.org/constitution/Austria_1991>',
#  '1983': '<http://www.constituteproject.org/constitution/Austria_1992>',
#  '1984': '<http://www.constituteproject.org/constitution/Austria_1993>',
#  '1985': '<http://www.constituteproject.org/constitution/Austria_1994>',
#  '1293': '<http://www.constituteproject.org/constitution/Austria_1996>',
#  '1294': '<http://www.constituteproject.org/constitution/Austria_1997>',
#  '1295': '<http://www.constituteproject.org/constitution/Austria_1998>',
#  '1296': '<http://www.constituteproject.org/constitution/Austria_1999>',
#  '59': '<http://www.constituteproject.org/constitution/Austria_2000>',
#  '1570': '<http://www.constituteproject.org/constitution/Austria_2001>',
#  '60': '<http://www.constituteproject.org/constitution/Austria_2002>',
#  '1571': '<http://www.constituteproject.org/constitution/Austria_2003>',
#  '61': '<http://www.constituteproject.org/constitution/Austria_2004>',
#  '3723': '<http://www.constituteproject.org/constitution/Austria_2005>',
#  '3729': '<http://www.constituteproject.org/constitution/Austria_2007>',
#  '3736': '<http://www.constituteproject.org/constitution/Austria_2008>',
#  '3750': '<http://www.constituteproject.org/constitution/Austria_2009>',
#  '3751': '<http://www.constituteproject.org/constitution/Austria_2010>',
#  '4115': '<http://www.constituteproject.org/constitution/Austria_2011>',
#  '4116': '<http://www.constituteproject.org/constitution/Austria_2012>',
#  '4117': '<http://www.constituteproject.org/constitution/Austria_2013>',
#  '10024': '<http://www.constituteproject.org/constitution/Austria_2014>',
#  '10025': '<http://www.constituteproject.org/constitution/Austria_2016>',
#  '10147': '<http://www.constituteproject.org/constitution/Austria_2017>',
#  '10171': '<http://www.constituteproject.org/constitution/Austria_2018>',
#  '10214': '<http://www.constituteproject.org/constitution/Austria_2019>',
#  '10301': '<http://www.constituteproject.org/constitution/Austria_2020>',
#  '10315': '<http://www.constituteproject.org/constitution/Austria_2021>',
#  '3690': '<http://www.constituteproject.org/constitution/Austria_Hungary_1848>',
#  '1955': '<http://www.constituteproject.org/constitution/Austria_Hungary_1849>',
#  '1957': '<http://www.constituteproject.org/constitution/Austria_Hungary_1867>',
#  '3832': '<http://www.constituteproject.org/constitution/Austria_Hungary_1907>',
#  '3297': '<http://www.constituteproject.org/constitution/Azerbaijan_1978>',
#  '3298': '<http://www.constituteproject.org/constitution/Azerbaijan_1986>',
#  '65': '<http://www.constituteproject.org/constitution/Azerbaijan_1991>',
#  '66': '<http://www.constituteproject.org/constitution/Azerbaijan_1995>',
#  '67': '<http://www.constituteproject.org/constitution/Azerbaijan_2002>',
#  '3752': '<http://www.constituteproject.org/constitution/Azerbaijan_2009>',
#  '10043': '<http://www.constituteproject.org/constitution/Azerbaijan_2016>',
#  '3226': '<http://www.constituteproject.org/constitution/Baden_1818>',
#  '3227': '<http://www.constituteproject.org/constitution/Baden_1825>',
#  '3228': '<http://www.constituteproject.org/constitution/Baden_1831>',
#  '3229': '<http://www.constituteproject.org/constitution/Baden_1841>',
#  '3230': '<http://www.constituteproject.org/constitution/Baden_1849>',
#  '3231': '<http://www.constituteproject.org/constitution/Baden_1862>',
#  '3232': '<http://www.constituteproject.org/constitution/Baden_1867>',
#  '3233': '<http://www.constituteproject.org/constitution/Baden_1868>',
#  '3234': '<http://www.constituteproject.org/constitution/Baden_1869>',
#  '3235': '<http://www.constituteproject.org/constitution/Baden_1870>',
#  '68': '<http://www.constituteproject.org/constitution/Bahamas_1973>',
#  '70': '<http://www.constituteproject.org/constitution/Bahrain_1973>',
#  '1986': '<http://www.constituteproject.org/constitution/Bahrain_1975>',
#  '71': '<http://www.constituteproject.org/constitution/Bahrain_2002>',
#  '3891': '<http://www.constituteproject.org/constitution/Bahrain_2012>',
#  '10088': '<http://www.constituteproject.org/constitution/Bahrain_2017>',
#  '72': '<http://www.constituteproject.org/constitution/Bangladesh_1972>',
#  '1987': '<http://www.constituteproject.org/constitution/Bangladesh_1973>',
#  '1988': '<http://www.constituteproject.org/constitution/Bangladesh_1974>',
#  '1298': '<http://www.constituteproject.org/constitution/Bangladesh_1975>',
#  '1300': '<http://www.constituteproject.org/constitution/Bangladesh_1977>',
#  '1989': '<http://www.constituteproject.org/constitution/Bangladesh_1978>',
#  '1990': '<http://www.constituteproject.org/constitution/Bangladesh_1979>',
#  '1991': '<http://www.constituteproject.org/constitution/Bangladesh_1981>',
#  '1301': '<http://www.constituteproject.org/constitution/Bangladesh_1982>',
#  '1303': '<http://www.constituteproject.org/constitution/Bangladesh_1986>',
#  '1304': '<http://www.constituteproject.org/constitution/Bangladesh_1988>',
#  '1305': '<http://www.constituteproject.org/constitution/Bangladesh_1989>',
#  '1992': '<http://www.constituteproject.org/constitution/Bangladesh_1990>',
#  '73': '<http://www.constituteproject.org/constitution/Bangladesh_1991>',
#  '74': '<http://www.constituteproject.org/constitution/Bangladesh_1996>',
#  '1993': '<http://www.constituteproject.org/constitution/Bangladesh_2004>',
#  '3879': '<http://www.constituteproject.org/constitution/Bangladesh_2011>',
#  '4294': '<http://www.constituteproject.org/constitution/Bangladesh_2014>',
#  '10193': '<http://www.constituteproject.org/constitution/Bangladesh_2018>',
#  '75': '<http://www.constituteproject.org/constitution/Barbados_1966>',
#  '1306': '<http://www.constituteproject.org/constitution/Barbados_1974>',
#  '1308': '<http://www.constituteproject.org/constitution/Barbados_1980>',
#  '1309': '<http://www.constituteproject.org/constitution/Barbados_1981>',
#  '1310': '<http://www.constituteproject.org/constitution/Barbados_1989>',
#  '1994': '<http://www.constituteproject.org/constitution/Barbados_1990>',
#  '1995': '<http://www.constituteproject.org/constitution/Barbados_1992>',
#  '76': '<http://www.constituteproject.org/constitution/Barbados_1995>',
#  '3474': '<http://www.constituteproject.org/constitution/Barbados_2000>',
#  '1996': '<http://www.constituteproject.org/constitution/Barbados_2002>',
#  '1997': '<http://www.constituteproject.org/constitution/Barbados_2003>',
#  '3887': '<http://www.constituteproject.org/constitution/Barbados_2005>',
#  '3888': '<http://www.constituteproject.org/constitution/Barbados_2007>',
#  '10194': '<http://www.constituteproject.org/constitution/Barbados_2009>',
#  '10195': '<http://www.constituteproject.org/constitution/Barbados_2010>',
#  '10196': '<http://www.constituteproject.org/constitution/Barbados_2018>',
#  '10197': '<http://www.constituteproject.org/constitution/Barbados_2019>',
#  '10287': '<http://www.constituteproject.org/constitution/Barbados_2020>',
#  '10316': '<http://www.constituteproject.org/constitution/Barbados_2021>',
#  '3215': '<http://www.constituteproject.org/constitution/Bavaria_1808>',
#  '1998': '<http://www.constituteproject.org/constitution/Bavaria_1818>',
#  '3216': '<http://www.constituteproject.org/constitution/Bavaria_1825>',
#  '3217': '<http://www.constituteproject.org/constitution/Bavaria_1828>',
#  '3218': '<http://www.constituteproject.org/constitution/Bavaria_1831>',
#  '3219': '<http://www.constituteproject.org/constitution/Bavaria_1834>',
#  '3220': '<http://www.constituteproject.org/constitution/Bavaria_1837>',
#  '3221': '<http://www.constituteproject.org/constitution/Bavaria_1840>',
#  '3222': '<http://www.constituteproject.org/constitution/Bavaria_1843>',
#  '3223': '<http://www.constituteproject.org/constitution/Bavaria_1846>',
#  '3224': '<http://www.constituteproject.org/constitution/Bavaria_1848>',
#  '1999': '<http://www.constituteproject.org/constitution/Bavaria_1852>',
#  '2000': '<http://www.constituteproject.org/constitution/Bavaria_1861>',
#  '2001': '<http://www.constituteproject.org/constitution/Bavaria_1865>',
#  '2002': '<http://www.constituteproject.org/constitution/Bavaria_1867>',
#  '2003': '<http://www.constituteproject.org/constitution/Bavaria_1868>',
#  '2004': '<http://www.constituteproject.org/constitution/Bavaria_1869>',
#  '2005': '<http://www.constituteproject.org/constitution/Bavaria_1871>',
#  '81': '<http://www.constituteproject.org/constitution/Belarus_1994>',
#  '82': '<http://www.constituteproject.org/constitution/Belarus_1996>',
#  '2006': '<http://www.constituteproject.org/constitution/Belarus_2004>',
#  '1931': '<http://www.constituteproject.org/constitution/Belgium_1831>',
#  '84': '<http://www.constituteproject.org/constitution/Belgium_1893>',
#  '85': '<http://www.constituteproject.org/constitution/Belgium_1920>',
#  '83': '<http://www.constituteproject.org/constitution/Belgium_1921>',
#  '2008': '<http://www.constituteproject.org/constitution/Belgium_1968>',
#  '2009': '<http://www.constituteproject.org/constitution/Belgium_1969>',
#  '87': '<http://www.constituteproject.org/constitution/Belgium_1970>',
#  '1311': '<http://www.constituteproject.org/constitution/Belgium_1971>',
#  '2010': '<http://www.constituteproject.org/constitution/Belgium_1980>',
#  '2011': '<http://www.constituteproject.org/constitution/Belgium_1981>',
#  '2012': '<http://www.constituteproject.org/constitution/Belgium_1983>',
#  '2013': '<http://www.constituteproject.org/constitution/Belgium_1984>',
#  '2014': '<http://www.constituteproject.org/constitution/Belgium_1985>',
#  '1312': '<http://www.constituteproject.org/constitution/Belgium_1988>',
#  '2015': '<http://www.constituteproject.org/constitution/Belgium_1989>',
#  '2016': '<http://www.constituteproject.org/constitution/Belgium_1991>',
#  '88': '<http://www.constituteproject.org/constitution/Belgium_1993>',
#  '89': '<http://www.constituteproject.org/constitution/Belgium_1994>',
#  '2017': '<http://www.constituteproject.org/constitution/Belgium_1996>',
#  '1313': '<http://www.constituteproject.org/constitution/Belgium_1997>',
#  '2018': '<http://www.constituteproject.org/constitution/Belgium_1998>',
#  '2019': '<http://www.constituteproject.org/constitution/Belgium_1999>',
#  '1314': '<http://www.constituteproject.org/constitution/Belgium_2000>',
#  '1315': '<http://www.constituteproject.org/constitution/Belgium_2001>',
#  '90': '<http://www.constituteproject.org/constitution/Belgium_2002>',
#  '4040': '<http://www.constituteproject.org/constitution/Belgium_2003>',
#  '2020': '<http://www.constituteproject.org/constitution/Belgium_2004>',
#  '91': '<http://www.constituteproject.org/constitution/Belgium_2005>',
#  '3737': '<http://www.constituteproject.org/constitution/Belgium_2007>',
#  '3738': '<http://www.constituteproject.org/constitution/Belgium_2008>',
#  '3925': '<http://www.constituteproject.org/constitution/Belgium_2012>',
#  '4272': '<http://www.constituteproject.org/constitution/Belgium_2014>',
#  '10215': '<http://www.constituteproject.org/constitution/Belgium_2017>',
#  '10216': '<http://www.constituteproject.org/constitution/Belgium_2019>',
#  '10317': '<http://www.constituteproject.org/constitution/Belgium_2021>',
#  '92': '<http://www.constituteproject.org/constitution/Belize_1981>',
#  '1135': '<http://www.constituteproject.org/constitution/Belize_1985>',
#  '93': '<http://www.constituteproject.org/constitution/Belize_1988>',
#  '3475': '<http://www.constituteproject.org/constitution/Belize_1999>',
#  '94': '<http://www.constituteproject.org/constitution/Belize_2001>',
#  '3810': '<http://www.constituteproject.org/constitution/Belize_2005>',
#  '3811': '<http://www.constituteproject.org/constitution/Belize_2008>',
#  '3812': '<http://www.constituteproject.org/constitution/Belize_2010>',
#  '4118': '<http://www.constituteproject.org/constitution/Belize_2011>',
#  '10217': '<http://www.constituteproject.org/constitution/Belize_2016>',
#  '10318': '<http://www.constituteproject.org/constitution/Belize_2021>',
#  '3360': '<http://www.constituteproject.org/constitution/Benin_1959>',
#  '96': '<http://www.constituteproject.org/constitution/Benin_1960>',
#  '2021': '<http://www.constituteproject.org/constitution/Benin_1963>',
#  '97': '<http://www.constituteproject.org/constitution/Benin_1964>',
#  '2022': '<http://www.constituteproject.org/constitution/Benin_1965>',
#  '2023': '<http://www.constituteproject.org/constitution/Benin_1968>',
#  '2024': '<http://www.constituteproject.org/constitution/Benin_1970>',
#  '2025': '<http://www.constituteproject.org/constitution/Benin_1972>',
#  '3361': '<http://www.constituteproject.org/constitution/Benin_1979>',
#  '2026': '<http://www.constituteproject.org/constitution/Benin_1984>',
#  '98': '<http://www.constituteproject.org/constitution/Benin_1990>',
#  '10218': '<http://www.constituteproject.org/constitution/Benin_2019>',
#  '1319': '<http://www.constituteproject.org/constitution/Bhutan_1953>',
#  '2027': '<http://www.constituteproject.org/constitution/Bhutan_1968>',
#  '2028': '<http://www.constituteproject.org/constitution/Bhutan_1979>',
#  '100': '<http://www.constituteproject.org/constitution/Bhutan_1981>',
#  '1888': '<http://www.constituteproject.org/constitution/Bhutan_2005>',
#  '3739': '<http://www.constituteproject.org/constitution/Bhutan_2008>',
#  '102': '<http://www.constituteproject.org/constitution/Bolivia_1826>',
#  '103': '<http://www.constituteproject.org/constitution/Bolivia_1831>',
#  '104': '<http://www.constituteproject.org/constitution/Bolivia_1834>',
#  '105': '<http://www.constituteproject.org/constitution/Bolivia_1839>',
#  '106': '<http://www.constituteproject.org/constitution/Bolivia_1843>',
#  '107': '<http://www.constituteproject.org/constitution/Bolivia_1851>',
#  '108': '<http://www.constituteproject.org/constitution/Bolivia_1861>',
#  '109': '<http://www.constituteproject.org/constitution/Bolivia_1868>',
#  '110': '<http://www.constituteproject.org/constitution/Bolivia_1871>',
#  '111': '<http://www.constituteproject.org/constitution/Bolivia_1878>',
#  '112': '<http://www.constituteproject.org/constitution/Bolivia_1880>',
#  '3451': '<http://www.constituteproject.org/constitution/Bolivia_1881>',
#  '3476': '<http://www.constituteproject.org/constitution/Bolivia_1882>',
#  '3452': '<http://www.constituteproject.org/constitution/Bolivia_1888>',
#  '3478': '<http://www.constituteproject.org/constitution/Bolivia_1898>',
#  '3453': '<http://www.constituteproject.org/constitution/Bolivia_1902>',
#  '3454': '<http://www.constituteproject.org/constitution/Bolivia_1905>',
#  '3481': '<http://www.constituteproject.org/constitution/Bolivia_1920>',
#  '3482': '<http://www.constituteproject.org/constitution/Bolivia_1921>',
#  '2030': '<http://www.constituteproject.org/constitution/Bolivia_1931>',
#  '113': '<http://www.constituteproject.org/constitution/Bolivia_1938>',
#  '2031': '<http://www.constituteproject.org/constitution/Bolivia_1939>',
#  '115': '<http://www.constituteproject.org/constitution/Bolivia_1945>',
#  '116': '<http://www.constituteproject.org/constitution/Bolivia_1947>',
#  '117': '<http://www.constituteproject.org/constitution/Bolivia_1961>',
#  '2032': '<http://www.constituteproject.org/constitution/Bolivia_1964>',
#  '118': '<http://www.constituteproject.org/constitution/Bolivia_1967>',
#  '2033': '<http://www.constituteproject.org/constitution/Bolivia_1968>',
#  '119': '<http://www.constituteproject.org/constitution/Bolivia_1994>',
#  '120': '<http://www.constituteproject.org/constitution/Bolivia_2002>',
#  '2034': '<http://www.constituteproject.org/constitution/Bolivia_2004>',
#  '2035': '<http://www.constituteproject.org/constitution/Bolivia_2005>',
#  '3689': '<http://www.constituteproject.org/constitution/Bolivia_2009>',
#  '3274': '<http://www.constituteproject.org/constitution/Bosnia_Herzegovina_1910>',
#  '129': '<http://www.constituteproject.org/constitution/Bosnia_Herzegovina_1995>',
#  '3753': '<http://www.constituteproject.org/constitution/Bosnia_Herzegovina_2009>',
#  '130': '<http://www.constituteproject.org/constitution/Botswana_1966>',
#  '2036': '<http://www.constituteproject.org/constitution/Botswana_1969>',
#  '2037': '<http://www.constituteproject.org/constitution/Botswana_1970>',
#  '1321': '<http://www.constituteproject.org/constitution/Botswana_1972>',
#  '1322': '<http://www.constituteproject.org/constitution/Botswana_1973>',
#  '1323': '<http://www.constituteproject.org/constitution/Botswana_1978>',
#  '2038': '<http://www.constituteproject.org/constitution/Botswana_1982>',
#  '131': '<http://www.constituteproject.org/constitution/Botswana_1983>',
#  '132': '<http://www.constituteproject.org/constitution/Botswana_1987>',
#  '133': '<http://www.constituteproject.org/constitution/Botswana_1992>',
#  '4092': '<http://www.constituteproject.org/constitution/Botswana_1993>',
#  '134': '<http://www.constituteproject.org/constitution/Botswana_1997>',
#  '4093': '<http://www.constituteproject.org/constitution/Botswana_1999>',
#  '2040': '<http://www.constituteproject.org/constitution/Botswana_2002>',
#  '4094': '<http://www.constituteproject.org/constitution/Botswana_2005>',
#  '10198': '<http://www.constituteproject.org/constitution/Botswana_2016>',
#  '10319': '<http://www.constituteproject.org/constitution/Botswana_2021>',
#  '135': '<http://www.constituteproject.org/constitution/Brazil_1824>',
#  '136': '<http://www.constituteproject.org/constitution/Brazil_1891>',
#  '2041': '<http://www.constituteproject.org/constitution/Brazil_1926>',
#  '137': '<http://www.constituteproject.org/constitution/Brazil_1930>',
#  '138': '<http://www.constituteproject.org/constitution/Brazil_1934>',
#  '2042': '<http://www.constituteproject.org/constitution/Brazil_1935>',
#  '139': '<http://www.constituteproject.org/constitution/Brazil_1937>',
#  '2043': '<http://www.constituteproject.org/constitution/Brazil_1938>',
#  '3485': '<http://www.constituteproject.org/constitution/Brazil_1939>',
#  '2044': '<http://www.constituteproject.org/constitution/Brazil_1940>',
#  '2045': '<http://www.constituteproject.org/constitution/Brazil_1942>',
#  '2046': '<http://www.constituteproject.org/constitution/Brazil_1945>',
#  '140': '<http://www.constituteproject.org/constitution/Brazil_1946>',
#  '3486': '<http://www.constituteproject.org/constitution/Brazil_1950>',
#  '2047': '<http://www.constituteproject.org/constitution/Brazil_1956>',
#  '2048': '<http://www.constituteproject.org/constitution/Brazil_1961>',
#  '2049': '<http://www.constituteproject.org/constitution/Brazil_1963>',
#  '2050': '<http://www.constituteproject.org/constitution/Brazil_1964>',
#  '2051': '<http://www.constituteproject.org/constitution/Brazil_1965>',
#  '2052': '<http://www.constituteproject.org/constitution/Brazil_1966>',
#  '141': '<http://www.constituteproject.org/constitution/Brazil_1967>',
#  '2053': '<http://www.constituteproject.org/constitution/Brazil_1968>',
#  '142': '<http://www.constituteproject.org/constitution/Brazil_1969>',
#  '2054': '<http://www.constituteproject.org/constitution/Brazil_1972>',
#  '2055': '<http://www.constituteproject.org/constitution/Brazil_1975>',
#  '2056': '<http://www.constituteproject.org/constitution/Brazil_1976>',
#  '2057': '<http://www.constituteproject.org/constitution/Brazil_1977>',
#  '2058': '<http://www.constituteproject.org/constitution/Brazil_1978>',
#  '2059': '<http://www.constituteproject.org/constitution/Brazil_1979>',
#  '2060': '<http://www.constituteproject.org/constitution/Brazil_1980>',
#  '2061': '<http://www.constituteproject.org/constitution/Brazil_1981>',
#  '2062': '<http://www.constituteproject.org/constitution/Brazil_1982>',
#  '3487': '<http://www.constituteproject.org/constitution/Brazil_1983>',
#  '2063': '<http://www.constituteproject.org/constitution/Brazil_1985>',
#  '143': '<http://www.constituteproject.org/constitution/Brazil_1988>',
#  '1116': '<http://www.constituteproject.org/constitution/Brazil_1992>',
#  '1117': '<http://www.constituteproject.org/constitution/Brazil_1993>',
#  '1118': '<http://www.constituteproject.org/constitution/Brazil_1994>',
#  '1119': '<http://www.constituteproject.org/constitution/Brazil_1995>',
#  '1120': '<http://www.constituteproject.org/constitution/Brazil_1996>',
#  '1121': '<http://www.constituteproject.org/constitution/Brazil_1997>',
#  '1122': '<http://www.constituteproject.org/constitution/Brazil_1998>',
#  '1123': '<http://www.constituteproject.org/constitution/Brazil_1999>',
#  '1124': '<http://www.constituteproject.org/constitution/Brazil_2000>',
#  '1125': '<http://www.constituteproject.org/constitution/Brazil_2001>',
#  '144': '<http://www.constituteproject.org/constitution/Brazil_2002>',
#  '1115': '<http://www.constituteproject.org/constitution/Brazil_2003>',
#  '145': '<http://www.constituteproject.org/constitution/Brazil_2004>',
#  '2064': '<http://www.constituteproject.org/constitution/Brazil_2005>',
#  '3926': '<http://www.constituteproject.org/constitution/Brazil_2006>',
#  '3927': '<http://www.constituteproject.org/constitution/Brazil_2007>',
#  '3928': '<http://www.constituteproject.org/constitution/Brazil_2008>',
#  '3761': '<http://www.constituteproject.org/constitution/Brazil_2009>',
#  '3762': '<http://www.constituteproject.org/constitution/Brazil_2010>',
#  '3929': '<http://www.constituteproject.org/constitution/Brazil_2011>',
#  '3930': '<http://www.constituteproject.org/constitution/Brazil_2012>',
#  '3931': '<http://www.constituteproject.org/constitution/Brazil_2013>',
#  '4119': '<http://www.constituteproject.org/constitution/Brazil_2014>',
#  '4390': '<http://www.constituteproject.org/constitution/Brazil_2015>',
#  '10026': '<http://www.constituteproject.org/constitution/Brazil_2016>',
#  '10134': '<http://www.constituteproject.org/constitution/Brazil_2017>',
#  '10219': '<http://www.constituteproject.org/constitution/Brazil_2019>',
#  '10303': '<http://www.constituteproject.org/constitution/Brazil_2020>',
#  '10320': '<http://www.constituteproject.org/constitution/Brazil_2021>',
#  '3419': '<http://www.constituteproject.org/constitution/Brunei_1959>',
#  '3420': '<http://www.constituteproject.org/constitution/Brunei_1961>',
#  '3421': '<http://www.constituteproject.org/constitution/Brunei_1963>',
#  '3422': '<http://www.constituteproject.org/constitution/Brunei_1964>',
#  '3423': '<http://www.constituteproject.org/constitution/Brunei_1983>',
#  '147': '<http://www.constituteproject.org/constitution/Brunei_1984>',
#  '3763': '<http://www.constituteproject.org/constitution/Brunei_2004>',
#  '3764': '<http://www.constituteproject.org/constitution/Brunei_2006>',
#  '148': '<http://www.constituteproject.org/constitution/Bulgaria_1879>',
#  '2065': '<http://www.constituteproject.org/constitution/Bulgaria_1881>',
#  '2066': '<http://www.constituteproject.org/constitution/Bulgaria_1883>',
#  '2067': '<http://www.constituteproject.org/constitution/Bulgaria_1893>',
#  '149': '<http://www.constituteproject.org/constitution/Bulgaria_1911>',
#  '2068': '<http://www.constituteproject.org/constitution/Bulgaria_1934>',
#  '2069': '<http://www.constituteproject.org/constitution/Bulgaria_1938>',
#  '150': '<http://www.constituteproject.org/constitution/Bulgaria_1947>',
#  '151': '<http://www.constituteproject.org/constitution/Bulgaria_1961>',
#  '152': '<http://www.constituteproject.org/constitution/Bulgaria_1965>',
#  '3276': '<http://www.constituteproject.org/constitution/Bulgaria_1969>',
#  '153': '<http://www.constituteproject.org/constitution/Bulgaria_1971>',
#  '154': '<http://www.constituteproject.org/constitution/Bulgaria_1990>',
#  '155': '<http://www.constituteproject.org/constitution/Bulgaria_1991>',
#  '156': '<http://www.constituteproject.org/constitution/Bulgaria_2003>',
#  '2070': '<http://www.constituteproject.org/constitution/Bulgaria_2005>',
#  '3277': '<http://www.constituteproject.org/constitution/Bulgaria_2006>',
#  '3278': '<http://www.constituteproject.org/constitution/Bulgaria_2007>',
#  '10006': '<http://www.constituteproject.org/constitution/Bulgaria_2015>',
#  '158': '<http://www.constituteproject.org/constitution/Burkina_Faso_1960>',
#  '2071': '<http://www.constituteproject.org/constitution/Burkina_Faso_1963>',
#  '2072': '<http://www.constituteproject.org/constitution/Burkina_Faso_1966>',
#  '1326': '<http://www.constituteproject.org/constitution/Burkina_Faso_1970>',
#  '2073': '<http://www.constituteproject.org/constitution/Burkina_Faso_1974>',
#  '1327': '<http://www.constituteproject.org/constitution/Burkina_Faso_1977>',
#  '2074': '<http://www.constituteproject.org/constitution/Burkina_Faso_1980>',
#  '1328': '<http://www.constituteproject.org/constitution/Burkina_Faso_1983>',
#  '1896': '<http://www.constituteproject.org/constitution/Burkina_Faso_1988>',
#  '159': '<http://www.constituteproject.org/constitution/Burkina_Faso_1991>',
#  '160': '<http://www.constituteproject.org/constitution/Burkina_Faso_1997>',
#  '2075': '<http://www.constituteproject.org/constitution/Burkina_Faso_2000>',
#  '2076': '<http://www.constituteproject.org/constitution/Burkina_Faso_2002>',
#  '4003': '<http://www.constituteproject.org/constitution/Burkina_Faso_2009>',
#  '4004': '<http://www.constituteproject.org/constitution/Burkina_Faso_2012>',
#  '10066': '<http://www.constituteproject.org/constitution/Burkina_Faso_2013>',
#  '10068': '<http://www.constituteproject.org/constitution/Burkina_Faso_2014>',
#  '10067': '<http://www.constituteproject.org/constitution/Burkina_Faso_2015>',
#  '3381': '<http://www.constituteproject.org/constitution/Burundi_1961>',
#  '167': '<http://www.constituteproject.org/constitution/Burundi_1962>',
#  '2077': '<http://www.constituteproject.org/constitution/Burundi_1966>',
#  '1329': '<http://www.constituteproject.org/constitution/Burundi_1974>',
#  '1330': '<http://www.constituteproject.org/constitution/Burundi_1976>',
#  '1331': '<http://www.constituteproject.org/constitution/Burundi_1981>',
#  '1332': '<http://www.constituteproject.org/constitution/Burundi_1987>',
#  '1333': '<http://www.constituteproject.org/constitution/Burundi_1992>',
#  '2078': '<http://www.constituteproject.org/constitution/Burundi_1996>',
#  '168': '<http://www.constituteproject.org/constitution/Burundi_1998>',
#  '3952': '<http://www.constituteproject.org/constitution/Burundi_2004>',
#  '1881': '<http://www.constituteproject.org/constitution/Burundi_2005>',
#  '10157': '<http://www.constituteproject.org/constitution/Burundi_2018>',
#  '3414': '<http://www.constituteproject.org/constitution/Cambodia_1947>',
#  '170': '<http://www.constituteproject.org/constitution/Cambodia_1956>',
#  '171': '<http://www.constituteproject.org/constitution/Cambodia_1957>',
#  '172': '<http://www.constituteproject.org/constitution/Cambodia_1958>',
#  '173': '<http://www.constituteproject.org/constitution/Cambodia_1959>',
#  '174': '<http://www.constituteproject.org/constitution/Cambodia_1964>',
#  '175': '<http://www.constituteproject.org/constitution/Cambodia_1970>',
#  '1901': '<http://www.constituteproject.org/constitution/Cambodia_1972>',
#  '3415': '<http://www.constituteproject.org/constitution/Cambodia_1973>',
#  '1903': '<http://www.constituteproject.org/constitution/Cambodia_1976>',
#  '176': '<http://www.constituteproject.org/constitution/Cambodia_1981>',
#  '1334': '<http://www.constituteproject.org/constitution/Cambodia_1989>',
#  '177': '<http://www.constituteproject.org/constitution/Cambodia_1993>',
#  '4120': '<http://www.constituteproject.org/constitution/Cambodia_1994>',
#  '178': '<http://www.constituteproject.org/constitution/Cambodia_1999>',
#  '4121': '<http://www.constituteproject.org/constitution/Cambodia_2001>',
#  '4122': '<http://www.constituteproject.org/constitution/Cambodia_2005>',
#  '4123': '<http://www.constituteproject.org/constitution/Cambodia_2006>',
#  '4124': '<http://www.constituteproject.org/constitution/Cambodia_2008>',
#  '10220': '<http://www.constituteproject.org/constitution/Cambodia_2014>',
#  '179': '<http://www.constituteproject.org/constitution/Cameroon_1960>',
#  '180': '<http://www.constituteproject.org/constitution/Cameroon_1961>',
#  '2079': '<http://www.constituteproject.org/constitution/Cameroon_1969>',
#  '181': '<http://www.constituteproject.org/constitution/Cameroon_1972>',
#  '1335': '<http://www.constituteproject.org/constitution/Cameroon_1975>',
#  '1337': '<http://www.constituteproject.org/constitution/Cameroon_1984>',
#  '2080': '<http://www.constituteproject.org/constitution/Cameroon_1995>',
#  '182': '<http://www.constituteproject.org/constitution/Cameroon_1996>',
#  '3932': '<http://www.constituteproject.org/constitution/Cameroon_2008>',
#  '3156': '<http://www.constituteproject.org/constitution/Canada_1763>',
#  '3157': '<http://www.constituteproject.org/constitution/Canada_1791>',
#  '185': '<http://www.constituteproject.org/constitution/Canada_1867>',
#  '2081': '<http://www.constituteproject.org/constitution/Canada_1871>',
#  '2082': '<http://www.constituteproject.org/constitution/Canada_1875>',
#  '2083': '<http://www.constituteproject.org/constitution/Canada_1886>',
#  '3488': '<http://www.constituteproject.org/constitution/Canada_1893>',
#  '2084': '<http://www.constituteproject.org/constitution/Canada_1907>',
#  '2085': '<http://www.constituteproject.org/constitution/Canada_1915>',
#  '3489': '<http://www.constituteproject.org/constitution/Canada_1916>',
#  '3490': '<http://www.constituteproject.org/constitution/Canada_1927>',
#  '3491': '<http://www.constituteproject.org/constitution/Canada_1930>',
#  '2086': '<http://www.constituteproject.org/constitution/Canada_1940>',
#  '3492': '<http://www.constituteproject.org/constitution/Canada_1943>',
#  '3493': '<http://www.constituteproject.org/constitution/Canada_1946>',
#  '3494': '<http://www.constituteproject.org/constitution/Canada_1949>',
#  '3495': '<http://www.constituteproject.org/constitution/Canada_1951>',
#  '3496': '<http://www.constituteproject.org/constitution/Canada_1952>',
#  '1338': '<http://www.constituteproject.org/constitution/Canada_1960>',
#  '2087': '<http://www.constituteproject.org/constitution/Canada_1964>',
#  '1339': '<http://www.constituteproject.org/constitution/Canada_1965>',
#  '2088': '<http://www.constituteproject.org/constitution/Canada_1974>',
#  '1341': '<http://www.constituteproject.org/constitution/Canada_1975>',
#  '186': '<http://www.constituteproject.org/constitution/Canada_1982>',
#  '1343': '<http://www.constituteproject.org/constitution/Canada_1983>',
#  '3497': '<http://www.constituteproject.org/constitution/Canada_1986>',
#  '2090': '<http://www.constituteproject.org/constitution/Canada_1987>',
#  '1344': '<http://www.constituteproject.org/constitution/Canada_1992>',
#  '1345': '<http://www.constituteproject.org/constitution/Canada_1993>',
#  '1346': '<http://www.constituteproject.org/constitution/Canada_1997>',
#  '3498': '<http://www.constituteproject.org/constitution/Canada_1998>',
#  '187': '<http://www.constituteproject.org/constitution/Canada_1999>',
#  '2091': '<http://www.constituteproject.org/constitution/Canada_2001>',
#  '3933': '<http://www.constituteproject.org/constitution/Canada_2011>',
#  '1347': '<http://www.constituteproject.org/constitution/Cape_Verde_1980>',
#  '2092': '<http://www.constituteproject.org/constitution/Cape_Verde_1981>',
#  '2093': '<http://www.constituteproject.org/constitution/Cape_Verde_1988>',
#  '2094': '<http://www.constituteproject.org/constitution/Cape_Verde_1990>',
#  '188': '<http://www.constituteproject.org/constitution/Cape_Verde_1992>',
#  '1877': '<http://www.constituteproject.org/constitution/Cape_Verde_1995>',
#  '1878': '<http://www.constituteproject.org/constitution/Cape_Verde_1999>',
#  '4125': '<http://www.constituteproject.org/constitution/Cape_Verde_2010>',
#  '3370': '<http://www.constituteproject.org/constitution/Central_African_Republic_1959>',
#  '190': '<http://www.constituteproject.org/constitution/Central_African_Republic_1960>',
#  '191': '<http://www.constituteproject.org/constitution/Central_African_Republic_1961>',
#  '192': '<http://www.constituteproject.org/constitution/Central_African_Republic_1962>',
#  '2095': '<http://www.constituteproject.org/constitution/Central_African_Republic_1963>',
#  '2096': '<http://www.constituteproject.org/constitution/Central_African_Republic_1964>',
#  '2097': '<http://www.constituteproject.org/constitution/Central_African_Republic_1966>',
#  '1348': '<http://www.constituteproject.org/constitution/Central_African_Republic_1976>',
#  '2098': '<http://www.constituteproject.org/constitution/Central_African_Republic_1979>',
#  '1349': '<http://www.constituteproject.org/constitution/Central_African_Republic_1981>',
#  '1350': '<http://www.constituteproject.org/constitution/Central_African_Republic_1986>',
#  '193': '<http://www.constituteproject.org/constitution/Central_African_Republic_1994>',
#  '2099': '<http://www.constituteproject.org/constitution/Central_African_Republic_2003>',
#  '1889': '<http://www.constituteproject.org/constitution/Central_African_Republic_2004>',
#  '3934': '<http://www.constituteproject.org/constitution/Central_African_Republic_2010>',
#  '4126': '<http://www.constituteproject.org/constitution/Central_African_Republic_2013>',
#  '4388': '<http://www.constituteproject.org/constitution/Central_African_Republic_2016>',
#  '3371': '<http://www.constituteproject.org/constitution/Chad_1959>',
#  '195': '<http://www.constituteproject.org/constitution/Chad_1960>',
#  '196': '<http://www.constituteproject.org/constitution/Chad_1962>',
#  '2100': '<http://www.constituteproject.org/constitution/Chad_1965>',
#  '1351': '<http://www.constituteproject.org/constitution/Chad_1967>',
#  '2101': '<http://www.constituteproject.org/constitution/Chad_1975>',
#  '197': '<http://www.constituteproject.org/constitution/Chad_1978>',
#  '198': '<http://www.constituteproject.org/constitution/Chad_1982>',
#  '1352': '<http://www.constituteproject.org/constitution/Chad_1989>',
#  '2102': '<http://www.constituteproject.org/constitution/Chad_1990>',
#  '199': '<http://www.constituteproject.org/constitution/Chad_1993>',
#  '2103': '<http://www.constituteproject.org/constitution/Chad_1995>',
#  '200': '<http://www.constituteproject.org/constitution/Chad_1996>',
#  '2104': '<http://www.constituteproject.org/constitution/Chad_2005>',
#  '10069': '<http://www.constituteproject.org/constitution/Chad_2013>',
#  '10090': '<http://www.constituteproject.org/constitution/Chad_2015>',
#  '10159': '<http://www.constituteproject.org/constitution/Chad_2018>',
#  '10321': '<http://www.constituteproject.org/constitution/Chad_2021>',
#  '3184': '<http://www.constituteproject.org/constitution/Chile_1811>',
#  '3185': '<http://www.constituteproject.org/constitution/Chile_1812>',
#  '3186': '<http://www.constituteproject.org/constitution/Chile_1814>',
#  '204': '<http://www.constituteproject.org/constitution/Chile_1818>',
#  '205': '<http://www.constituteproject.org/constitution/Chile_1822>',
#  '206': '<http://www.constituteproject.org/constitution/Chile_1823>',
#  '2105': '<http://www.constituteproject.org/constitution/Chile_1824>',
#  '207': '<http://www.constituteproject.org/constitution/Chile_1826>',
#  '208': '<http://www.constituteproject.org/constitution/Chile_1828>',
#  '210': '<http://www.constituteproject.org/constitution/Chile_1833>',
#  '3457': '<http://www.constituteproject.org/constitution/Chile_1865>',
#  '2106': '<http://www.constituteproject.org/constitution/Chile_1871>',
#  '2107': '<http://www.constituteproject.org/constitution/Chile_1873>',
#  '2108': '<http://www.constituteproject.org/constitution/Chile_1874>',
#  '2109': '<http://www.constituteproject.org/constitution/Chile_1882>',
#  '2110': '<http://www.constituteproject.org/constitution/Chile_1884>',
#  '3459': '<http://www.constituteproject.org/constitution/Chile_1887>',
#  '2111': '<http://www.constituteproject.org/constitution/Chile_1888>',
#  '2112': '<http://www.constituteproject.org/constitution/Chile_1891>',
#  '2113': '<http://www.constituteproject.org/constitution/Chile_1892>',
#  '2114': '<http://www.constituteproject.org/constitution/Chile_1893>',
#  '2115': '<http://www.constituteproject.org/constitution/Chile_1917>',
#  '2116': '<http://www.constituteproject.org/constitution/Chile_1924>',
#  '211': '<http://www.constituteproject.org/constitution/Chile_1925>',
#  '1354': '<http://www.constituteproject.org/constitution/Chile_1943>',
#  '2117': '<http://www.constituteproject.org/constitution/Chile_1957>',
#  '2118': '<http://www.constituteproject.org/constitution/Chile_1959>',
#  '2119': '<http://www.constituteproject.org/constitution/Chile_1963>',
#  '1355': '<http://www.constituteproject.org/constitution/Chile_1967>',
#  '2120': '<http://www.constituteproject.org/constitution/Chile_1970>',
#  '2121': '<http://www.constituteproject.org/constitution/Chile_1971>',
#  '2123': '<http://www.constituteproject.org/constitution/Chile_1973>',
#  '2124': '<http://www.constituteproject.org/constitution/Chile_1974>',
#  '3499': '<http://www.constituteproject.org/constitution/Chile_1975>',
#  '2125': '<http://www.constituteproject.org/constitution/Chile_1976>',
#  '3500': '<http://www.constituteproject.org/constitution/Chile_1977>',
#  '3501': '<http://www.constituteproject.org/constitution/Chile_1979>',
#  '212': '<http://www.constituteproject.org/constitution/Chile_1980>',
#  '3187': '<http://www.constituteproject.org/constitution/Chile_1986>',
#  '215': '<http://www.constituteproject.org/constitution/Chile_1989>',
#  '1357': '<http://www.constituteproject.org/constitution/Chile_1991>',
#  '1358': '<http://www.constituteproject.org/constitution/Chile_1994>',
#  '1359': '<http://www.constituteproject.org/constitution/Chile_1996>',
#  '1360': '<http://www.constituteproject.org/constitution/Chile_1997>',
#  '3805': '<http://www.constituteproject.org/constitution/Chile_1998>',
#  '2126': '<http://www.constituteproject.org/constitution/Chile_1999>',
#  '2127': '<http://www.constituteproject.org/constitution/Chile_2000>',
#  '216': '<http://www.constituteproject.org/constitution/Chile_2001>',
#  '2128': '<http://www.constituteproject.org/constitution/Chile_2003>',
#  '2129': '<http://www.constituteproject.org/constitution/Chile_2005>',
# ...
#  '243': '<http://www.constituteproject.org/constitution/Costa_Rica_1844>',
#  '244': '<http://www.constituteproject.org/constitution/Costa_Rica_1847>',
#  '245': '<http://www.constituteproject.org/constitution/Costa_Rica_1848>',
#  '246': '<http://www.constituteproject.org/constitution/Costa_Rica_1859>',
#  '247': '<http://www.constituteproject.org/constitution/Costa_Rica_1869>',
#  '1913': '<http://www.constituteproject.org/constitution/Costa_Rica_1871>',
#  '3447': '<http://www.constituteproject.org/constitution/Costa_Rica_1882>',
#  '3531': '<http://www.constituteproject.org/constitution/Costa_Rica_1886>',
#  '3448': '<http://www.constituteproject.org/constitution/Costa_Rica_1888>',
#  '3533': '<http://www.constituteproject.org/constitution/Costa_Rica_1895>',
#  '3535': '<http://www.constituteproject.org/constitution/Costa_Rica_1898>',
#  '3536': '<http://www.constituteproject.org/constitution/Costa_Rica_1903>',
#  '3449': '<http://www.constituteproject.org/constitution/Costa_Rica_1905>',
#  '3538': '<http://www.constituteproject.org/constitution/Costa_Rica_1910>',
#  '3539': '<http://www.constituteproject.org/constitution/Costa_Rica_1913>',
#  '249': '<http://www.constituteproject.org/constitution/Costa_Rica_1917>',
#  '3468': '<http://www.constituteproject.org/constitution/Costa_Rica_1919>',
#  '3540': '<http://www.constituteproject.org/constitution/Costa_Rica_1924>',
#  '3541': '<http://www.constituteproject.org/constitution/Costa_Rica_1926>',
#  '3542': '<http://www.constituteproject.org/constitution/Costa_Rica_1927>',
#  '3543': '<http://www.constituteproject.org/constitution/Costa_Rica_1933>',
#  '3544': '<http://www.constituteproject.org/constitution/Costa_Rica_1935>',
#  '2169': '<http://www.constituteproject.org/constitution/Costa_Rica_1936>',
#  '2170': '<http://www.constituteproject.org/constitution/Costa_Rica_1937>',
#  '2171': '<http://www.constituteproject.org/constitution/Costa_Rica_1941>',
#  '2172': '<http://www.constituteproject.org/constitution/Costa_Rica_1943>',
#  '2173': '<http://www.constituteproject.org/constitution/Costa_Rica_1944>',
#  '248': '<http://www.constituteproject.org/constitution/Costa_Rica_1946>',
#  '2174': '<http://www.constituteproject.org/constitution/Costa_Rica_1948>',
#  '250': '<http://www.constituteproject.org/constitution/Costa_Rica_1949>',
#  '2175': '<http://www.constituteproject.org/constitution/Costa_Rica_1954>',
#  '2176': '<http://www.constituteproject.org/constitution/Costa_Rica_1956>',
#  '3545': '<http://www.constituteproject.org/constitution/Costa_Rica_1957>',
#  '3546': '<http://www.constituteproject.org/constitution/Costa_Rica_1958>',
#  '2177': '<http://www.constituteproject.org/constitution/Costa_Rica_1959>',
#  '2178': '<http://www.constituteproject.org/constitution/Costa_Rica_1961>',
#  '1380': '<http://www.constituteproject.org/constitution/Costa_Rica_1963>',
#  '2179': '<http://www.constituteproject.org/constitution/Costa_Rica_1965>',
#  '2180': '<http://www.constituteproject.org/constitution/Costa_Rica_1968>',
#  '2181': '<http://www.constituteproject.org/constitution/Costa_Rica_1969>',
#  '2182': '<http://www.constituteproject.org/constitution/Costa_Rica_1971>',
#  '2183': '<http://www.constituteproject.org/constitution/Costa_Rica_1972>',
#  '2184': '<http://www.constituteproject.org/constitution/Costa_Rica_1973>',
#  '2185': '<http://www.constituteproject.org/constitution/Costa_Rica_1975>',
#  '1381': '<http://www.constituteproject.org/constitution/Costa_Rica_1977>',
#  '3547': '<http://www.constituteproject.org/constitution/Costa_Rica_1981>',
#  '3548': '<http://www.constituteproject.org/constitution/Costa_Rica_1982>',
#  '3549': '<http://www.constituteproject.org/constitution/Costa_Rica_1984>',
#  '3550': '<http://www.constituteproject.org/constitution/Costa_Rica_1987>',
#  '3551': '<http://www.constituteproject.org/constitution/Costa_Rica_1989>',
#  '3552': '<http://www.constituteproject.org/constitution/Costa_Rica_1991>',
#  '251': '<http://www.constituteproject.org/constitution/Costa_Rica_1993>',
#  '2186': '<http://www.constituteproject.org/constitution/Costa_Rica_1994>',
#  '2187': '<http://www.constituteproject.org/constitution/Costa_Rica_1995>',
#  '2188': '<http://www.constituteproject.org/constitution/Costa_Rica_1996>',
#  '2189': '<http://www.constituteproject.org/constitution/Costa_Rica_1997>',
#  '2190': '<http://www.constituteproject.org/constitution/Costa_Rica_1999>',
#  '2191': '<http://www.constituteproject.org/constitution/Costa_Rica_2000>',
#  '2192': '<http://www.constituteproject.org/constitution/Costa_Rica_2001>',
#  '2193': '<http://www.constituteproject.org/constitution/Costa_Rica_2002>',
#  '252': '<http://www.constituteproject.org/constitution/Costa_Rica_2003>',
#  '3937': '<http://www.constituteproject.org/constitution/Costa_Rica_2011>',
#  '10031': '<http://www.constituteproject.org/constitution/Costa_Rica_2015>',
#  '10223': '<http://www.constituteproject.org/constitution/Costa_Rica_2018>',
#  '10224': '<http://www.constituteproject.org/constitution/Costa_Rica_2019>',
#  '10290': '<http://www.constituteproject.org/constitution/Costa_Rica_2020>',
#  '3363': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1959>',
#  '2194': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1960>',
#  '2195': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1963>',
#  '2196': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1975>',
#  '1382': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1980>',
#  '1384': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1985>',
#  '10155': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1986>',
#  '1385': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1990>',
#  '1386': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1994>',
#  '4316': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1995>',
#  '1387': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1998>',
#  '2197': '<http://www.constituteproject.org/constitution/Cote_DIvoire_1999>',
#  '1383': '<http://www.constituteproject.org/constitution/Cote_DIvoire_2000>',
#  '4309': '<http://www.constituteproject.org/constitution/Cote_DIvoire_2012>',
#  '10032': '<http://www.constituteproject.org/constitution/Cote_DIvoire_2016>',
#  '10323': '<http://www.constituteproject.org/constitution/Cote_DIvoire_2020>',
#  '1388': '<http://www.constituteproject.org/constitution/Croatia_1991>',
#  '3272': '<http://www.constituteproject.org/constitution/Croatia_1997>',
#  '3273': '<http://www.constituteproject.org/constitution/Croatia_2000>',
#  '1151': '<http://www.constituteproject.org/constitution/Croatia_2001>',
#  '3922': '<http://www.constituteproject.org/constitution/Croatia_2010>',
#  '10071': '<http://www.constituteproject.org/constitution/Croatia_2013>',
#  '3159': '<http://www.constituteproject.org/constitution/Cuba_1901>',
#  '2198': '<http://www.constituteproject.org/constitution/Cuba_1928>',
#  '267': '<http://www.constituteproject.org/constitution/Cuba_1933>',
#  '268': '<http://www.constituteproject.org/constitution/Cuba_1934>',
#  '269': '<http://www.constituteproject.org/constitution/Cuba_1935>',
#  '3553': '<http://www.constituteproject.org/constitution/Cuba_1936>',
#  '270': '<http://www.constituteproject.org/constitution/Cuba_1940>',
#  '3554': '<http://www.constituteproject.org/constitution/Cuba_1946>',
#  '271': '<http://www.constituteproject.org/constitution/Cuba_1952>',
#  '3555': '<http://www.constituteproject.org/constitution/Cuba_1953>',
#  '272': '<http://www.constituteproject.org/constitution/Cuba_1959>',
#  '3556': '<http://www.constituteproject.org/constitution/Cuba_1960>',
#  '2199': '<http://www.constituteproject.org/constitution/Cuba_1962>',
#  '273': '<http://www.constituteproject.org/constitution/Cuba_1976>',
#  '1391': '<http://www.constituteproject.org/constitution/Cuba_1978>',
#  '274': '<http://www.constituteproject.org/constitution/Cuba_1992>',
#  '275': '<http://www.constituteproject.org/constitution/Cuba_2002>',
#  '10170': '<http://www.constituteproject.org/constitution/Cuba_2018D>',
#  '10190': '<http://www.constituteproject.org/constitution/Cuba_2019>',
#  '1152': '<http://www.constituteproject.org/constitution/Cyprus_1960>',
#  '3938': '<http://www.constituteproject.org/constitution/Cyprus_1989>',
#  '2200': '<http://www.constituteproject.org/constitution/Cyprus_1996>',
#  '3939': '<http://www.constituteproject.org/constitution/Cyprus_2002>',
#  '3940': '<http://www.constituteproject.org/constitution/Cyprus_2006>',
#  '3941': '<http://www.constituteproject.org/constitution/Cyprus_2010>',
#  '4013': '<http://www.constituteproject.org/constitution/Cyprus_2013>',
#  '10044': '<http://www.constituteproject.org/constitution/Cyprus_2015>',
#  '10045': '<http://www.constituteproject.org/constitution/Cyprus_2016>',
#  '10324': '<http://www.constituteproject.org/constitution/Cyprus_2020>',
#  '280': '<http://www.constituteproject.org/constitution/Czech_Republic_1993>',
#  '2202': '<http://www.constituteproject.org/constitution/Czech_Republic_1998>',
#  '2203': '<http://www.constituteproject.org/constitution/Czech_Republic_2000>',
#  '282': '<http://www.constituteproject.org/constitution/Czech_Republic_2001>',
#  '283': '<http://www.constituteproject.org/constitution/Czech_Republic_2002>',
#  '4006': '<http://www.constituteproject.org/constitution/Czech_Republic_2009>',
#  '4007': '<http://www.constituteproject.org/constitution/Czech_Republic_2012>',
#  '4008': '<http://www.constituteproject.org/constitution/Czech_Republic_2013>',
#  '3257': '<http://www.constituteproject.org/constitution/Czechoslovakia_1918>',
#  '2204': '<http://www.constituteproject.org/constitution/Czechoslovakia_1919>',
#  '276': '<http://www.constituteproject.org/constitution/Czechoslovakia_1920>',
#  '2205': '<http://www.constituteproject.org/constitution/Czechoslovakia_1926>',
#  '2206': '<http://www.constituteproject.org/constitution/Czechoslovakia_1935>',
#  '277': '<http://www.constituteproject.org/constitution/Czechoslovakia_1948>',
#  '278': '<http://www.constituteproject.org/constitution/Czechoslovakia_1960>',
#  '2209': '<http://www.constituteproject.org/constitution/Czechoslovakia_1968>',
#  '279': '<http://www.constituteproject.org/constitution/Czechoslovakia_1969>',
#  '2210': '<http://www.constituteproject.org/constitution/Czechoslovakia_1970>',
#  '2211': '<http://www.constituteproject.org/constitution/Czechoslovakia_1971>',
#  '3258': '<http://www.constituteproject.org/constitution/Czechoslovakia_1975>',
#  '2212': '<http://www.constituteproject.org/constitution/Czechoslovakia_1978>',
#  '2214': '<http://www.constituteproject.org/constitution/Czechoslovakia_1988>',
#  '2215': '<http://www.constituteproject.org/constitution/Czechoslovakia_1989>',
#  '2216': '<http://www.constituteproject.org/constitution/Czechoslovakia_1990>',
#  '2217': '<http://www.constituteproject.org/constitution/Czechoslovakia_1991>',
#  '3259': '<http://www.constituteproject.org/constitution/Czechoslovakia_1992>',
#  '288': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1960>',
#  '2152': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1961>',
#  '289': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1964>',
#  '4289': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1965>',
#  '4290': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1966>',
#  '1394': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1967>',
#  '2153': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1970>',
#  '2154': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1971>',
#  '2155': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1972>',
#  '4291': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1973>',
#  '2156': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1974>',
#  '1919': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1978>',
#  '2157': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1980>',
#  '2158': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1982>',
#  '2159': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1988>',
#  '2160': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1990>',
#  '3372': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_1997>',
#  '1879': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_2003>',
#  '1895': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_2005>',
#  '3936': '<http://www.constituteproject.org/constitution/Democratic_Republic_of_the_Congo_2011>',
#  '290': '<http://www.constituteproject.org/constitution/Denmark_1849>',
#  '4185': '<http://www.constituteproject.org/constitution/Denmark_1863>',
#  '1153': '<http://www.constituteproject.org/constitution/Denmark_1866>',
#  '1154': '<http://www.constituteproject.org/constitution/Denmark_1915>',
#  '1155': '<http://www.constituteproject.org/constitution/Denmark_1920>',
#  '293': '<http://www.constituteproject.org/constitution/Denmark_1953>',
#  '1396': '<http://www.constituteproject.org/constitution/Djibouti_1977>',
#  '294': '<http://www.constituteproject.org/constitution/Djibouti_1992>',
#  '3814': '<http://www.constituteproject.org/constitution/Djibouti_2006>',
#  '3815': '<http://www.constituteproject.org/constitution/Djibouti_2008>',
#  '3770': '<http://www.constituteproject.org/constitution/Djibouti_2010>',
#  '295': '<http://www.constituteproject.org/constitution/Dominica_1978>',
#  '2218': '<http://www.constituteproject.org/constitution/Dominica_1983>',
#  '296': '<http://www.constituteproject.org/constitution/Dominica_1984>',
#  '10072': '<http://www.constituteproject.org/constitution/Dominica_2014>',
#  '3163': '<http://www.constituteproject.org/constitution/Dominican_Republic_1821>',
#  '298': '<http://www.constituteproject.org/constitution/Dominican_Republic_1844>',
#  '300': '<http://www.constituteproject.org/constitution/Dominican_Republic_1854>',
#  '301': '<http://www.constituteproject.org/constitution/Dominican_Republic_1858>',
#  '2219': '<http://www.constituteproject.org/constitution/Dominican_Republic_1861>',
#  '302': '<http://www.constituteproject.org/constitution/Dominican_Republic_1865>',
#  '303': '<http://www.constituteproject.org/constitution/Dominican_Republic_1866>',
#  '2220': '<http://www.constituteproject.org/constitution/Dominican_Republic_1868>',
#  '304': '<http://www.constituteproject.org/constitution/Dominican_Republic_1872>',
#  '305': '<http://www.constituteproject.org/constitution/Dominican_Republic_1874>',
#  '306': '<http://www.constituteproject.org/constitution/Dominican_Republic_1875>',
#  '307': '<http://www.constituteproject.org/constitution/Dominican_Republic_1877>',
#  '308': '<http://www.constituteproject.org/constitution/Dominican_Republic_1878>',
#  '309': '<http://www.constituteproject.org/constitution/Dominican_Republic_1879>',
#  '310': '<http://www.constituteproject.org/constitution/Dominican_Republic_1880>',
#  '311': '<http://www.constituteproject.org/constitution/Dominican_Republic_1881>',
#  '312': '<http://www.constituteproject.org/constitution/Dominican_Republic_1887>',
#  '313': '<http://www.constituteproject.org/constitution/Dominican_Republic_1896>',
#  '314': '<http://www.constituteproject.org/constitution/Dominican_Republic_1907>',
#  '315': '<http://www.constituteproject.org/constitution/Dominican_Republic_1908>',
#  '316': '<http://www.constituteproject.org/constitution/Dominican_Republic_1924>',
#  '317': '<http://www.constituteproject.org/constitution/Dominican_Republic_1927>',
#  '319': '<http://www.constituteproject.org/constitution/Dominican_Republic_1929>',
#  '320': '<http://www.constituteproject.org/constitution/Dominican_Republic_1934>',
#  '321': '<http://www.constituteproject.org/constitution/Dominican_Republic_1942>',
#  ...}

# %%
m = about.search('<event id="3799" rdf:about="http://www.constituteproject.org/constitution/Abkhazia_1994" country="Abkhazia">')
print(m.group())
# Out:
# rdf:about="http://www.constituteproject.org/constitution/Abkhazia_1994"

# %% [markdown]
# # Análisis y extraccion de Metadata (old)

# %% [raw]
# clasesMetadata = {
#     "isConstitutionOf" : "<http://www.constituteproject.org/constitution/isConstitutionOf>"
# }
#
# resource = re.compile('rdf:resource="http:.*"')

# %% [raw]
# metadataTtl = open("metadata.ttl", "w")
# metadata = open("metadata.xml", "r")
#
# for metadato in metadata:
#     match = about.search(metadato)
#     if match != None:
#         sujeto = "<" + match.group()[11:-1] + ">"
#
#     match = resource.search(metadato)
#     if match != None:
#         objeto = "<" + match.group()[14:-1] + ">"
#         metadataTtl.write(formato.format(sujeto, clasesMetadata["isConstitutionOf"], objeto))
#
#
#
# metadataTtl.close()
# metadata.close()

# %% [markdown]
# # Extracción eventos (new)

# %% [raw]
# wgcCode = re.compile("WGCODE>\d*<")
# countryId = re.compile("country_id>.*<")
# metadata = open("metadata.xml", "r")
#
# countriesDict = {}
#
# for metadato in metadata:
#
#     match = wgcCode.search(metadato)
#     if match != None:
#         code = match.group()[7:-1]
#
#     match = resource.search(metadato)
#     if match != None:
#         objeto = "<" + match.group()[14:-1] + ">"
#
#
#     match = countryId.search(metadato)
#     if match != None:
#         country_id = match.group()[11:-1]
#         countriesDict[code] = (objeto, country_id)
#
#
# metadata.close()

# %%
import pandas as pd

# %% [raw]
# dt = pd.read_csv("ccpcce_v1_3.txt", sep="\t")
# dt

# %% [raw]
# events = dt[dt['evntid'].notnull()]
# events = events.astype({'evntid':int})
#
# events = events.sort_values(by = ['evntid'])
# events

# %% [raw]
# clasesEventos = {
#     "type": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>",
#     "event": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event>",
#     "eventId": "<http://www.constituteproject.org/constitution/id>",
#     "country": "<http://www.constituteproject.org/constitution/country>",
#     "eventType": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event_type>",
#     "eventYear": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#event_year>",
#     "isConstitutionOf" : "<http://www.constituteproject.org/constitution/isConstitutionOf>"
#     }

# %% [raw]
# newEvents = open("newEvents.ttl", "w")
#
# paisesSinDatos = set()
#
# dictEventos = {}
# for indice, row in events.iterrows():
#
#     if str(row['cowcode']) in countriesDict:
#         objeto = countriesDict[str(row['cowcode'])][0][:-1] + "_" + str(row['year']) + ">"
#         dictEventos[row['evntid']] = objeto
#
#         newEvents.write(formato.format(objeto, clasesEventos["type"], clasesEventos["event"]))
#         newEvents.write(formato.format(objeto, clasesEventos["eventId"], '"' + str(row["evntid"]) + '"'))
#         newEvents.write(formato.format(objeto, clasesEventos["country"], '"' + row["country"] + '"'))
#         newEvents.write(formato.format(objeto, clasesEventos["eventType"], '"' + row["evnttype"] + '"'))
#         newEvents.write(formato.format(objeto, clasesEventos["eventYear"], '"' + str(row["year"]) + '"'))
#         newEvents.write(formato.format(objeto, clasesEventos["isConstitutionOf"], countriesDict[str(row['cowcode'])][0]))
#
#     else:
#         paisesSinDatos.add((row['cowcode'],row['country']))
#
# newEvents.close()

# %% [raw]
# paisesSinDatos

# %% [raw]
# dictEventos

# %% [raw]
# countriesDict

# %% [markdown]
# # Extraccion datos duros

# %%
df = pd.read_stata('CCP_data/ccpcnc_v4/ccpcnc/ccpcnc_v4.dta')
df
# Out:
#        cowcode   country  year                   wg  \
# 0          396  Abkhazia  1994  0. Not in WG sample
# 1          396  Abkhazia  2008      1. In WG sample
# 2          396  Abkhazia  2009      1. In WG sample
# 3          396  Abkhazia  2010      1. In WG sample
# 4          396  Abkhazia  2011      1. In WG sample
# ...        ...       ...   ...                  ...
# 21336      552  Zimbabwe  2017      1. In WG sample
# 21337      552  Zimbabwe  2018      1. In WG sample
# 21338      552  Zimbabwe  2019      1. In WG sample
# 21339      552  Zimbabwe  2020      1. In WG sample
# 21340      552  Zimbabwe  2021      1. In WG sample
#
#             sample_deviation_type                             syst  systid  \
# 0      3. Pre-statehood/inherited     1. New constitutional system   995.0
# 1                             NaN  0. No new constitutional system   995.0
# 2                             NaN  0. No new constitutional system   995.0
# 3                             NaN  0. No new constitutional system   995.0
# 4                             NaN  0. No new constitutional system   995.0
# ...                           ...                              ...     ...
# 21336                         NaN  0. No new constitutional system  1011.0
# 21337                         NaN  0. No new constitutional system  1011.0
# 21338                         NaN  0. No new constitutional system  1011.0
# 21339                         NaN  0. No new constitutional system  1011.0
# 21340                         NaN  0. No new constitutional system  1011.0
#
#        systyear                        evnt   evntid  ...  \
# 0        1994.0     1. Constitutional event   3799.0  ...
# 1        1994.0  0. No constitutional event   3799.0  ...
# 2        1994.0  0. No constitutional event   3799.0  ...
# 3        1994.0  0. No constitutional event   3799.0  ...
# 4        1994.0  0. No constitutional event   3799.0  ...
# ...         ...                         ...      ...  ...
# 21336    2013.0     1. Constitutional event  10136.0  ...
# 21337    2013.0  0. No constitutional event  10136.0  ...
# 21338    2013.0  0. No constitutional event  10136.0  ...
# 21339    2013.0  0. No constitutional event  10136.0  ...
# 21340    2013.0     1. Constitutional event  10368.0  ...
#
#                     edfree_comments                    edfreel  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
# ...                             ...                        ...
# 21336  basic education for children  2. secondary/intermediate
# 21337  basic education for children  2. secondary/intermediate
# 21338  basic education for children  2. secondary/intermediate
# 21339  basic education for children  2. secondary/intermediate
# 21340  basic education for children  2. secondary/intermediate
#
#       edfreel_article                                   edfreel_comments  \
# 0
# 1
# 2
# 3
# 4
# ...               ...                                                ...
# 21336      27.1; 81.1  state must take all practical measures to prom...
# 21337      27.1; 81.1  state must take all practical measures to prom...
# 21338      27.1; 81.1  state must take all practical measures to prom...
# 21339      27.1; 81.1  state must take all practical measures to prom...
# 21340      27.1; 81.1  state must take all practical measures to prom...
#
#        acfree acfree_article  acfree_comments  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...            ...              ...
# 21336  1. yes         61.1.c
# 21337  1. yes         61.1.c
# 21338  1. yes         61.1.c
# 21339  1. yes         61.1.c
# 21340  1. yes         61.1.c
#
#                                                 achighed achighed_article  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...              ...
# 21336  96. other, please specify in the comments section         20; 75.1
# 21337  96. other, please specify in the comments section         20; 75.1
# 21338  96. other, please specify in the comments section         20; 75.1
# 21339  96. other, please specify in the comments section         20; 75.1
# 21340  96. other, please specify in the comments section         20; 75.1
#
#                                        achighed_comments
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 21336  state must take reasonable measures including ...
# 21337  state must take reasonable measures including ...
# 21338  state must take reasonable measures including ...
# 21339  state must take reasonable measures including ...
# 21340  state must take reasonable measures including ...
#
# [21341 rows x 2030 columns]

# %%
filtro = "1. Constitutional event"
dfFiltered = df[df['evnt'] == filtro ]
dfFiltered = dfFiltered.sort_values(by = ['evntid'])
dfFiltered = dfFiltered.astype({'evntid': int})
dfFiltered
# Out:
#        cowcode      country  year               wg sample_deviation_type  \
# 92         700  Afghanistan  1923  1. In WG sample                   NaN
# 100        700  Afghanistan  1931  1. In WG sample                   NaN
# 133        700  Afghanistan  1964  1. In WG sample                   NaN
# 146        700  Afghanistan  1977  1. In WG sample                   NaN
# 156        700  Afghanistan  1987  1. In WG sample                   NaN
# ...        ...          ...   ...              ...                   ...
# 20477      704   Uzbekistan  2018  1. In WG sample                   NaN
# 20478      704   Uzbekistan  2019  1. In WG sample                   NaN
# 20480      704   Uzbekistan  2021  1. In WG sample                   NaN
# 16728      340       Serbia  2021  1. In WG sample                   NaN
# 21340      552     Zimbabwe  2021  1. In WG sample                   NaN
#
#                                   syst  systid  systyear  \
# 92        1. New constitutional system   819.0    1923.0
# 100       1. New constitutional system   820.0    1931.0
# 133       1. New constitutional system   821.0    1964.0
# 146       1. New constitutional system   823.0    1977.0
# 156       1. New constitutional system   828.0    1987.0
# ...                                ...     ...       ...
# 20477  0. No new constitutional system   836.0    1992.0
# 20478  0. No new constitutional system   836.0    1992.0
# 20480  0. No new constitutional system   836.0    1992.0
# 16728  0. No new constitutional system   462.0    2006.0
# 21340  0. No new constitutional system  1011.0    2013.0
#
#                           evnt  evntid  ...               edfree_comments  \
# 92     1. Constitutional event       1  ...
# 100    1. Constitutional event       2  ...
# 133    1. Constitutional event       3  ...
# 146    1. Constitutional event       4  ...
# 156    1. Constitutional event       5  ...
# ...                        ...     ...  ...                           ...
# 20477  1. Constitutional event   10364  ...
# 20478  1. Constitutional event   10365  ...
# 20480  1. Constitutional event   10366  ...
# 16728  1. Constitutional event   10367  ...
# 21340  1. Constitutional event   10368  ...  basic education for children
#
#                            edfreel edfreel_article  \
# 92               98. not specified              14
# 100             99. not applicable
# 133              98. not specified
# 146    1. basic/elementary/primary              10
# 156              98. not specified
# ...                            ...             ...
# 20477    2. secondary/intermediate              41
# 20478    2. secondary/intermediate              41
# 20480    2. secondary/intermediate              41
# 16728    2. secondary/intermediate              71
# 21340    2. secondary/intermediate      27.1; 81.1
#
#                                         edfreel_comments  acfree  \
# 92                                                        1. yes
# 100                                                       1. yes
# 133                                                        2. no
# 146                                                        2. no
# 156                                                        2. no
# ...                                                  ...     ...
# 20477                                                     1. yes
# 20478                                                     1. yes
# 20480                                                     1. yes
# 16728                                                     1. yes
# 21340  state must take all practical measures to prom...  1. yes
#
#       acfree_article                                    acfree_comments  \
# 92        14; 15; 68  freedom of education is to be exercised in acc...
# 100               21  instruction in the knowledge of islam is unres...
# 133
# 146
# 156
# ...              ...                                                ...
# 20477
# 20478
# 20480
# 16728             72
# 21340         61.1.c
#
#                                                 achighed achighed_article  \
# 92                                                 3. no
# 100                                                3. no
# 133                                                3. no
# 146                                                3. no
# 156                                                3. no
# ...                                                  ...              ...
# 20477                                              3. no
# 20478                                              3. no
# 20480                                              3. no
# 16728                                             1. yes               71
# 21340  96. other, please specify in the comments section         20; 75.1
#
#                                        achighed_comments
# 92
# 100
# 133
# 146
# 156
# ...                                                  ...
# 20477
# 20478
# 20480
# 16728
# 21340  state must take reasonable measures including ...
#
# [4115 rows x 2030 columns]

# %% [markdown]
# ## Agregar eventos faltantes

# %%
prefijo = "<http://www.constituteproject.org/ontology/"
prefijo2 = "<http://www.constituteproject.org/constitution/"

eventosExtra = open("Ttl/eventosExtra.ttl", "w")

for index, row in dfFiltered.iterrows():
    if str(row['evntid']) not in dictEventos:
        country = row["country"]
        print(country)
        
        if country == "Sudan":
            objeto = prefijo + "Sudan_the>"
        
        elif country == "Gambia":
            objeto = prefijo + "Gambia__the>"
        
        elif country == "Niger":
            objeto = prefijo + "Niger_the>"
            
        elif country == "Kyrgyz Republic":
            objeto = prefijo + "Kyrgyzstan>"
            country = "Kyrgyz_Republic"
        
        elif country == "Moldova":
            objeto = prefijo + "Maldives>"
            
        elif country == "Slovak Republic":
            objeto = prefijo + "Slovakia>"
            country = "Slovakia"

        else:
            objeto = prefijo + country + ">"
        #print(objeto)
        #print(str(row["evntid"]), row["country"], str(row["year"]))
        
        sujeto = prefijo2 + country + "_" + str(row['year']) + ">"
        #print(sujeto)
        
        eventosExtra.write(formato.format(sujeto, clasesEventos["type"], clasesEventos["event"]))
        eventosExtra.write(formato.format(sujeto, clasesEventos["isConstitutionOf"], objeto))
        eventosExtra.write(formato.format(sujeto, clasesEventos["eventId"], '"' + str(row["evntid"]) + '"'))
        eventosExtra.write(formato.format(sujeto, clasesEventos["country"], '"' + row["country"] + '"'))
        eventosExtra.write(formato.format(sujeto, clasesEventos["eventType"], '"' + row["evnttype"][3:] + '"'))
        eventosExtra.write(formato.format(sujeto, clasesEventos["eventYear"], '"' + str(row["year"]) + '"'))
        
        dictEventos[str(row['evntid'])] = sujeto
        


        
eventosExtra.close()
# Out:
# Haiti
# Sudan
# Venezuela
# Gambia
# Gambia
# Chad
# Gambia
# Grenada
# Grenada
# Lesotho
# Niger
# Nigeria
# Pakistan
# Pakistan
# Lesotho
# Lesotho
# Lesotho
# Lesotho
# Liberia
# Nigeria
# Sudan
# Uganda
# Uganda
# Uganda
# Uganda
# Uganda
# Uganda
# Lesotho
# Pakistan
# Portugal
# Sudan
# Sudan
# Sudan
# Burundi
# Lesotho
# Pakistan
# Pakistan
# Pakistan
# Norway
# Tunisia
# Italy
# Kyrgyz Republic
# Liechtenstein
# Malta
# Mexico
# Moldova
# Moldova
# Myanmar
# Kosovo
# Luxembourg
# Nicaragua
# Nicaragua
# Oman
# Singapore
# Singapore
# Singapore
# Slovak Republic
# Sweden
# Sweden
# Switzerland
# Tonga
# Turkmenistan
# Turkmenistan
# Tuvalu
# Tuvalu
# Uzbekistan
# Uzbekistan
# Uzbekistan
# Serbia
# Zimbabwe

# %% [raw]
# newEventsV2 = open("newEventsV2.ttl", "w")
#
# for index, row in dfFiltered.iterrows():
#     if row['evntid'] not in dictEventos and str(row['cowcode']) in countriesDict:
#         sujeto = countriesDict[str(row['cowcode'])][0][:-1] + "_" + str(row['year']) + ">"
#         dictEventos[row['evntid']] = sujeto
#
#         newEventsV2.write(formato.format(sujeto, clasesEventos["type"], clasesEventos["event"]))
#         newEventsV2.write(formato.format(sujeto, clasesEventos["eventId"], '"' + str(row["evntid"]) + '"'))
#         newEventsV2.write(formato.format(sujeto, clasesEventos["country"], '"' + row["country"] + '"'))
#         newEventsV2.write(formato.format(sujeto, clasesEventos["eventType"], '"' + row["evnttype"] + '"'))
#         newEventsV2.write(formato.format(sujeto, clasesEventos["eventYear"], '"' + str(row["year"]) + '"'))
#         newEventsV2.write(formato.format(sujeto, clasesEventos["isConstitutionOf"], countriesDict[str(row['cowcode'])][0]))
#
# newEventsV2.close()

# %%
dfFiltered[dfFiltered['evntid'] == 2377]
# Out:
# Empty DataFrame
# Columns: [cowcode, country, year, wg, sample_deviation_type, syst, systid, systyear, evnt, evntid, evntyear, evnttype, multiple, c_inforce, coding_available, coding_imputed, imputed_evntid, imputed_evntyear, imputation_type, source, source_article, source_comments, langsrce, langsrce_article, langsrce_comments, translat, translat_article, translat_comments, doctit, doctit_article, doctit_comments, model, model_article, model_comments, length, length_article, length_comments, docs, docs_article, docs_comments, tranprov, tranprov_article, tranprov_comments, preamble, preamble_article, preamble_comments, preambw, preambw_article, preambw_comments, rightsw, rightsw_article, rightsw_comments, rghtwrds, rghtwrds_article, rghtwrds_comments, colony, colony_article, colony_comments, colrule, colrule_article, colrule_comments, indcon, indcon_article, indcon_comments, region_article, region_comments, region, regions, regions_article, regions_comments, prevcond, prevcond_article, prevcond_comments, truthcom, truthcom_article, truthcom_comments, prevlead, prevlead_article, prevlead_comments, democ, democ_article, democ_comments, demonum, demonum_article, demonum_comments, oath, oath_article, oath_comments, socialsm, socialsm_article, socialsm_comments, market, market_article, market_comments, forinves, forinves_article, forinves_comments, fortrad, fortrad_article, fortrad_comments, ...]
# Index: []
#
# [0 rows x 2030 columns]

# %% [raw]
# values = [955, 947, 946]
# dfFiltered = dfFiltered.query("cowcode not in @values")
# dfFiltered

# %%
dfFiltered = dfFiltered.astype(str)

# %%
for column in dfFiltered.columns:
    if 'cabinet' in column:
        print(column)
# Out:
# cabinet
# cabinet_article
# cabinet_comments

# %%
dfFiltered['uhterm']
# Out:
# 92            99
# 100            0
# 133      5; 3; 4
# 146           99
# 156            5
#           ...
# 20477         99
# 20478         99
# 20480         99
# 16728         99
# 21340          5
# Name: uhterm, Length: 4115, dtype: object

# %% [markdown]
# ## Análisis de datos

# %%
import numpy as np

# %%
clasesDatos = {
    "type": "<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>",
    "detalle": "<http://www.imfd.cl/ontologia/convencion/detalle_"
}

prefijo = "<http://www.constituteproject.org/ontology/"

dictHosrest = {
    1 : '"Debe pertenecer a un partido en específico."',
    2 : '"Debe pertenecer un genero en específico."',
    3 : '"Debe ser miembro de una denominacion religiosa en específico."',
    4 : '"Debe tener una identidad etnica específica."',
    5 : '"Debe ser ciudadano."',
    6 : '"Debe ser ciudadano nativo."',
    7 : '"Debe tener cierto nivel de educación."',
    8 : '"No debe ser transgresor de la ley."',
    9 : '"Deber haber sido residente en el país por un perdíodo de tiempo."',
    10: '"No debe estar casado con una persona que no es ciudadana."',
    11: '"Debe tener la nacionalidad del país."'
}

dictLhselect = {
    1 : '"Designados."',
    2 : '"Electos por un grupo de Elite."',
    3 : '"Electos por la ciudadanía."'    
}


dictLhrest = {
    1 : '"Debe pertenecer a un partido en específico."',
    2 : '"Debe pertenecer un genero en específico."',
    3 : '"Debe ser miembro de una denominacion religiosa en específico."',
    4 : '"Debe tener una identidad lingüistica/nacional/racial específica."',
    5 : '"Debe ser ciudadano."',
    6 : '"Debe ser ciudadano nativo."',
    7 : '"Debe tener cierto nivel de educación."',
    8 : '"No debe ser transgresor de la ley."',
    9 : '"Debe tener la nacionalidad del país."'
}

dictLhquota = {
    1 : '"Mujeres."',
    2 : '"Grupos Étnicos."',
    3 : '"Partidos Políticos."',
    4 : '"Religiones."',
    5 : '"Clases sociales o símilares."'
}

# %%
datos = open("Ttl/datosDuros.ttl", "w")

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["preamble"]:
        objeto = prefijo + "preamble>" 
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["colony"] or "2" in row["colony"]:
        objeto = prefijo + "colony>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["colony"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "colony>", '"Se deben abandonar los territorios ocupados."' ))
            
        elif "2" in row["colony"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "colony>", '"Se deben mantener los territorios ocupados."' ))
    
    if "1" in row["prevcond"]:
        objeto = prefijo + "prevcond>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["truthcom"]:
        objeto = prefijo + "truthcom>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["prevlead"] or "2" in row["prevlead"]:
        objeto = prefijo + "prevlead>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["prevlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "prevlead>", '"Los crímenes serán perdonados."' ))
            
        elif "2" in row["prevlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "prevlead>", '"Los crímenes son castigados."' ))
        
    if "1" in row["oath"]:
        objeto = prefijo + "oath>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["dignity"]:
        objeto = prefijo + "dignity>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["god"]:
        objeto = prefijo + "god>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["figures"]:
        objeto = prefijo + "figures>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["region"]:
        objeto = prefijo + "region>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["solid"]:
        objeto = prefijo + "solid>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["overthrw"]:
        objeto = prefijo + "overthrw>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["capital"]:
        objeto = prefijo + "capital>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["anthem"]:
        objeto = prefijo + "anthem>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["flag"]:
        objeto = prefijo + "flag>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
        
    if "1" in row["motto"]:
        objeto = prefijo + "motto>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["amend"]:
        objeto = prefijo + "amend>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["unamend"]:
        objeto = prefijo + "unamend>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["execindp"]:
        objeto = prefijo + "execindp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["execnum"] or "2" in row["execnum"] or "3" in row["execnum"]:
        objeto = prefijo + "execnum>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["execnum"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "execnum>", '"0"' ))
            
        elif "2" in row["execnum"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "execnum>", '"1"' ))
            
        elif "3" in row["execnum"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "execnum>", '"2"' ))
        
    if "1" in row["hoselect"] or "2" in row["hoselect"] or "3" in row["hoselect"]:
        objeto = prefijo + "hoselect>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hoselect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hoselect>", '"Sistema Hereditario/Seleccion Real."' ))
            
        elif "2" in row["hoselect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hoselect>", '"Eleccion ciudadana."' ))
            
        elif "3" in row["hoselect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hoselect>", '"Eleccion de grupo de Elite."' ))
        
    if "1" in row["hosterm"]:
        objeto = prefijo + "hosterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "100" in str(row["hosterm"]):
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterm>", '"Sin límite."' ))
            
        else: 
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterm>", '"' + str(row["hosterm"]) + '"' ))
        
    if "1" in row["hosterml"] or "2" in row["hosterml"] or "3" in row["hosterml"] or "4" in row["hosterml"] or "5" in row["hosterml"]:
        objeto = prefijo + "hosterml>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hosterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterml>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["hosterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterml>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["hosterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterml>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["hosterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterml>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["hosterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosterml>", '"Sin límite de periodos."' ))
            
    if "90" not in row["hosage"] and  "96" not in row["hosage"] and  "97" not in row["hosage"] and  "98" not in row["hosage"] and  "99" not in row["hosage"] and row["hosage"] != "nan":
        objeto = prefijo + "hosage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["hosage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosage>", '"Mayor de edad."' ))
            
        elif "16." in row["hosage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosage>", '"' + str(row["hosage"])[4:] + '"' ))
    
    typeHosrest = False
    for i in range(1,12):
        if str(i) in row["hosrest_" + str(i)]:
            typeHosrest = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosrest>", dictHosrest[i] ))
    
    if typeHosrest:
        objeto = prefijo + "hosrest>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["hosdiss"]:
        objeto = prefijo + "hosdiss>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["hossucc"] or "2" in row["hossucc"] or "3" in row["hossucc"] or "4" in row["hossucc"]:
        objeto = prefijo + "hossucc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hossucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hossucc>", '"Se implementa el proceso de seleccion normal."' ))
            
        elif "2" in row["hossucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hossucc>", '"El poder Legistaltivo escoge un sucesor."' ))
            
        elif "3" in row["hossucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hossucc>", '"El porder Judicial escoge un sucesor."' ))
            
        elif "4" in row["hossucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hossucc>", '"Se sigue una linea de sucesión predeterminada."' ))
            
    if "1" in row["hosimm"] or "2" in row["hosimm"] or "3" in row["hosimm"]:
        objeto = prefijo + "hosimm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hosimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosimm>", '"Sí, inmunidad absoluta."' ))
        
        elif "2" in row["hosimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosimm>", '"Sí, inmunidad limitada."' ))
            
        elif "3" in row["hosimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosimm>", '"No, denegación de inmunidad."' ))
            
    if "1" in row["hosstaff"]:
        objeto = prefijo + "hosstaff>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["hosdec"]:
        objeto = prefijo + "hosdec>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["hogelect"] or "2" in row["hogelect"] or "3" in row["hogelect"] or "4" in row["hogelect"]:
        objeto = prefijo + "hogelect>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hogelect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogelect>", '"Sistema Hereditario/Seleccion Real."' ))
        
        elif "2" in row["hogelect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogelect>", '"Eleccion ciudadana."' ))
            
        elif "3" in row["hogelect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogelect>", '"Eleccion de grupo de Elite."' ))
            
        elif "4" in row["hogelect"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogelect>", '"Designado."' ))
            
    if "99" not in row["hogterm"] and " 0" not in row["hogterm"] and row["hogterm"] != "":
        numero = re.compile("\d*")
        años = numero.search(row["hogterm"])
        
        if años != None and años.group() != '':
            objeto = prefijo + "hogterm>"
            datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

            if "100" in row["hogterm"]:
                datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterm>", '"Sin límite."' ))

            else:
                añosString = años.group()
                if "months" in row["hogterm"]:
                    añosString = str(int(años.group())/12)
                datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterm>", '"' + añosString + '"' ))
                
    if "1" in row["hogterml"] or "2" in row["hogterml"] or "3" in row["hogterml"] or "4" in row["hogterml"] or "5" in row["hogterml"]:
        objeto = prefijo + "hogterml>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hogterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterml>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["hogterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterml>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["hogterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterml>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["hogterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterml>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["hogterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogterml>", '"Sin límite de periodos."' ))
            

    if "90" not in row["hogage"] and  "96" not in row["hogage"] and  "97" not in row["hogage"] and  "98" not in row["hogage"] and  "99" not in row["hogage"] and row["hogage"] != "nan":
        objeto = prefijo + "hogage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
        if "1." in row["hogage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"Mayor de edad."' ))
            
        elif "16." in row["hogage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"' + str(row["hogage"])[4:] + '"' ))
            
    if "1" in row["hoglegr"] or "2" in row["hoglegr"] or "3" in row["hoglegr"]:
        objeto = prefijo + "hoglegr>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["hoglegr"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"Puede ser miembro de la legislatura."' ))
            
        elif "2." in row["hoglegr"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"No puede ser miembro de la legislatura."' ))
            
        elif "3." in row["hoglegr"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogage>", '"Puede ser miembro bajo requisitos."' ))
            
    typeHogrest = False
    for i in range(1,12):
        if str(i) in row["hogrest_" + str(i)]:
            typeHosrest = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hosgest>", dictHosrest[i] ))
    
    if typeHogrest:
        objeto = prefijo + "hogrest>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["hogdiss"] or "2" in row["hogdiss"] or "3" in row["hogdiss"]:
        objeto = prefijo + "hogdiss>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["hogsucc"] or "2" in row["hogsucc"] or "3" in row["hogsucc"] or "4" in row["hogsucc"]:
        objeto = prefijo + "hogsucc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hogsucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogsucc>", '"Se implementa el proceso de seleccion normal."' ))
            
        elif "2" in row["hogsucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogsucc>", '"El poder Legistaltivo escoge un sucesor."' ))
            
        elif "3" in row["hogsucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogsucc>", '"El porder Judicial escoge un sucesor."' ))
            
        elif "4" in row["hogsucc"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogsucc>", '"Se sigue una linea de sucesión predeterminada."' ))
    
    if "1" in row["hogimm"] or "2" in row["hogimm"] or "3" in row["hogimm"]:
        objeto = prefijo + "hogimm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["hogimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogimm>", '"Sí, inmunidad absoluta."' ))
        
        elif "2" in row["hogimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogimm>", '"Sí, inmunidad limitada."' ))
            
        elif "3" in row["hogimm"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "hogimm>", '"No, denegación de inmunidad."' ))
            
            
    if "1" in row["hogdec"]:
        objeto = prefijo + "hogdec>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["depexec"]:
        objeto = prefijo + "depexec>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["cabinet"]:
        objeto = prefijo + "cabinet>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["atgen"] or "2" in row["atgen"] or "3" in row["atgen"] or "3" in row["atgen"] or "5" in row["atgen"]:
        objeto = prefijo + "atgen>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["atgen"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "atgen>", '"Sólo para casos criminales."' ))
        
        elif "2" in row["atgen"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "atgen>", '"Sólo para casos civiles"' ))
            
        elif "3" in row["atgen"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "atgen>", '"La misma entidad para casos civiles y criminales."' ))
            
        elif "4" in row["atgen"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "atgen>", '"Diferentes enidades para casos civiles y criminales."' ))
            
        elif "5" in row["atgen"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "atgen>", '"No se hace diferencia entre casos civiles y criminales."' ))
    
    if "1" in row["em"]:
        objeto = prefijo + "em>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1." in row["housenum"] or "2." in row["housenum"] or "3." in row["housenum"]:
        objeto = prefijo + "housenum>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        datos.write(formato.format(sujeto, clasesDatos['detalle'] + "housenum>", '"' + row["housenum"][3:] + '"' ))
        
    if "1." in row["legjoint"] or "2." in row["legjoint"] or "3." in row["legjoint"]:
        objeto = prefijo + "legjoint>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["legjoint"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legjoint>", '"Hay una entidad especial compuesta por integrantes de ambas cámaras"' ))
            
        elif "2" in row["legjoint"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legjoint>", '"Sólo para coordinar legislaciones en paralelo."' ))
            
        elif "3" in row["legjoint"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legjoint>", '"Sólo bajo ciertas circunstancias."' ))
            
    
    if "1." in row["lhlead"] or "2." in row["lhlead"] or "3." in row["lhlead"] or "4." in row["lhlead"] or "5." in row["lhlead"]:
        objeto = prefijo + "lhlead>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["lhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhlead>", '"Jefe de Gobierno."' ))
            
        elif "2" in row["lhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhlead>", '"Miembro de la primera (o úinica) cámara."' ))
            
        elif "3" in row["lhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhlead>", '"Secretario Ejecutivo.."' ))
            
        elif "4" in row["lhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhlead>", '"Un miembro del poder Judicial."' ))
            
        elif "5" in row["lhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhlead>", '"Jefe de Estado."' ))
    
    numberRegex = re.compile("\d.*")
    typeLhseats = numberRegex.match(row["lhseats"])
    
    if typeLhseats != None and row["lhseats"] != "0" and row["lhseats"] != "99":
        objeto = prefijo + "lhseats>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhseats>", '"' + row["lhseats"] + '"' ))
    
    typeLhselect = False
    for i in range(1,4):
        if str(i) in row["lhselect_" + str(i)]:
            typeLhselect = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhselect>", dictLhselect[i] ))
    
    if typeLhselect:
        objeto = prefijo + "lhselect>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
   
    if "90." not in row["lhage"] and  "96." not in row["lhage"] and  "97." not in row["lhage"] and  "98." not in row["lhage"] and  "99." not in row["lhage"] and row["lhage"] != "nan":
        objeto = prefijo + "lhage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["lhage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhage>", '"Mayor de edad."' ))
            
        elif "16." in row["lhage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhage>", '"' + str(row["lhage"])[4:] + '"' ))
            
    
    typeLhrest = False
    for i in range(1,10):
        if str(i) in row["lhrest_" + str(i)]:
            typeLhrest = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhrest>", dictLhrest[i] ))
    
    if typeLhrest:
        objeto = prefijo + "lhrest>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1." in row["lhterm"] or "2." in row["lhterm"] or "3." in row["lhterm"] or "4." in row["lhterm"] or "5." in row["lhterm"] or "6. 6" in row["lhterm"] or "7." in row["lhterm"]:
        objeto = prefijo + "lhterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhterm>", '"' + row["lhterm"][3:] + '"' ))
      
    if "1" in row["lhtrmlim"] or "2" in row["lhtrmlim"] or "3" in row["lhtrmlim"] or "4" in row["lhtrmlim"] or "5" in row["lhtrmlim"]:
        objeto = prefijo + "lhtrmlim>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["lhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhtrmlim>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["lhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhtrmlim>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["lhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhtrmlim>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["lhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhtrmlim>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["lhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhtrmlim>", '"Sin límite de periodos."' ))
            
    
    if "1." in row["lhquota"]:
        objeto = prefijo + "lhquota>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    for i in range(1,6):
        if str(i) in row["lhquotad_" + str(i)]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lhquota>", dictLhquota[i] ))
            
    if "1." in row["uhlead"] or "2." in row["uhlead"] or "3." in row["uhlead"] or "4." in row["uhlead"] or "5." in row["uhlead"]:
        objeto = prefijo + "uhlead>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["uhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhlead>", '"Jefe de Gobierno."' ))
            
        elif "2" in row["uhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhlead>", '"Miembro de la segunda cámara."' ))
            
        elif "3" in row["uhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhlead>", '"Secretario Ejecutivo."' ))
            
        elif "4" in row["uhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhlead>", '"Un miembro del poder Judicial."' ))
            
        elif "5" in row["uhlead"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhlead>", '"Jefe de Estado."' ))
            
    typeUhseats = numberRegex.match(row["uhseats"])
    
    if typeUhseats != None and row["uhseats"] != "0" and row["uhseats"] != "99":
        objeto = prefijo + "uhseats>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhseats>", '"' + row["uhseats"] + '"' ))
        
    typeUhselect = False
    for i in range(1,4):
        if str(i) in row["uhselect_" + str(i)]:
            typeUhselect = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhselect>", dictLhselect[i] ))
    
    if typeUhselect:
        objeto = prefijo + "uhselect>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "90." not in row["uhage"] and  "96." not in row["uhage"] and  "97." not in row["uhage"] and  "98." not in row["uhage"] and  "99." not in row["uhage"] and row["uhage"] != "nan":
        objeto = prefijo + "uhage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["uhage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhage>", '"Mayor de edad."' ))
            
        elif "16." in row["uhage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhage>", '"' + str(row["uhage"])[4:] + '"' ))
            
    typeUhrest = False
    for i in range(1,10):
        if str(i) in row["uhrest_" + str(i)]:
            typeUhrest = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhrest>", dictLhrest[i] ))
    
    if typeUhrest:
        objeto = prefijo + "uhrest>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if row["uhterm"] != "99" and row["uhterm"] != "0" and row["uhterm"] != "": 
        objeto = prefijo + "uhterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhterm>", '"' + str(row["uhterm"]) + '"' ))
        
    if "1" in row["uhtrmlim"] or "2" in row["uhtrmlim"] or "3" in row["uhtrmlim"] or "4" in row["uhtrmlim"] or "5" in row["uhtrmlim"]:
        objeto = prefijo + "uhtrmlim>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["uhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhtrmlim>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["uhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhtrmlim>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["uhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhtrmlim>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["uhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhtrmlim>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["uhtrmlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhtrmlim>", '"Sin límite de periodos."' ))
    
    if "1." in row["uhquota"]:
        objeto = prefijo + "uhquota>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    for i in range(1,6):
        if str(i) in row["uhquotad_" + str(i)]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "uhquota>", dictLhquota[i] ))

# %% [markdown]
# ### Removal and Replacement

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["legdiss"] or "2" in row["legdiss"] or "3" in row["legdiss"] or "4" in row["legdiss"] or "5" in row["legdiss"]:
        objeto = prefijo + "legdiss>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["legdiss"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legdiss>", '"Jefe de Estado."' ))
            
        elif "2" in row["legdiss"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legdiss>", '"Jefe de Gobierno."' ))
        
        elif "3" in row["legdiss"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legdiss>", '"Jefe de Gobierno o Jefe de Estado."' ))
            
        elif "4" in row["legdiss"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legdiss>", '"El Gobierno/Gabinete."' ))
            
        elif "5" in row["legdiss"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legdiss>", '"La legislatura en sí misma."' ))
            
    if "1" in row["remleg"]:
        objeto = prefijo + "remleg>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "90." not in row["legrep"] and "96." not in row["legrep"] and "97." not in row["legrep"] and "98." not in row["legrep"] and "99." not in row["legrep"] and row["remleg"] != "nan":
        objeto = prefijo + "legrep>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Designado por el Jefe de Estado."' ))
            
        elif "2" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Designado por el Jefe de Gobierno."' ))
        
        elif "3" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Designado por el Gobierno/Gabinete."' ))
            
        elif "4" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Electo por la cámara respectiva."' ))
            
        elif "5" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Electo por ambas cámaras de la Legislatura."' ))
            
        elif "6" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Electo por la poblacion en una elección especial."' ))
            
        elif "7" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Ascenso del miembro suplementario."' ))
        
        elif "8" in row["legrep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legrep>", '"Es electa la siguiente persona en la lista."' ))
            
    if "1." in row["immunity"] or "2." in row["immunity"]:
        objeto = prefijo + "immunity>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["immunity"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "immunity>", '"Inmunidad Absoluta."' ))
            
        elif "1." in row["immunity"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "immunity>", '"Inmunidad Limitada."' ))

# %% [markdown]
# ### Oversight Powers

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1." in row["invexe"]:
        objeto = prefijo + "invexe>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Legislation

# %%
dictLegini = {
    1 : '"Jefe de Estado."',
    2 : '"Jefe de Gobierno."',
    3 : '"El Gobierno/Gabiente."',
    4 : '"Partidos Políticos."',
    5 : '"Miembros de la primera (o única) cámara de la Legislatura."',
    6 : '"Miembros de la segunda cámara de la Legislatura."',
    7 : '"El publico."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    typeLegini = False
    for i in range(1,8):
        if str(i) in row["leg_in_" + str(i)]:
            typeLegini = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legini>", dictLegini[i] ))
    
    if typeLegini:
        objeto = prefijo + "legini>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["legsupr"]:
        objeto = prefijo + "legsupr>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1." in row["legapp"] or "2." in row["legapp"] or "3." in row["legapp"] or "4." in row["legapp"] or "5." in row["legapp"]:
        objeto = prefijo + "legapp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["legapp"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legapp>", '"Jefe de Estado."' ))
            
        elif "2" in row["legapp"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legapp>", '"Jefe de Gobierno."' ))
        
        elif "3" in row["legapp"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legapp>", '"Jefe de Gobierno o Jefe de Estado."' ))
            
        elif "4" in row["legapp"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legapp>", '"El Gobierno/Gabinete."' ))
            
        elif "5" in row["legapp"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "legapp>", '"La legislación no requiere aprovación."' ))   
    
    if "1" in row["override"]:
        objeto = prefijo + "override>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Rules and Restrictions

# %%
dictExsess = {
    1: '"El Jefe de Estado."',
    2: '"El Jefe de Gobierno."',
    3: '"El Gobierno/Gabinete."',
    4: '"La primera (o única) cámara de la Legislatura."',
    5: '"La segunda cámara de la Legislatura."',
    6: '"La dos cámaras de la Legislatura en conjunto."'
}

dictIncome = {
    1: '"El Jefe de Estado."',
    2: '"El Jefe de Gobierno."',
    3: '"El Gobierno/Gabinete."',
    4: '"La primera (o única) cámara de la Legislatura."',
    5: '"La segunda cámara de la Legislatura."',
    6: '"La dos cámaras de la Legislatura en conjunto."',
    7: '"La comisión anti-corrupción."',
    8: '"Una Agencia Administrativa"'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "2." in row["attend"] or "3." in row["attend"]:
        objeto = prefijo + "attend>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

        if "2" in row["attend"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "attend>", '"La asistencia es obligatoria."' ))
        
        elif "3" in row["attend"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "attend>", '"la ausencia es penalizada después de cierto punto."' ))
            
    typeExsess = False
    for i in range(1,7):
        if str(i) in row["exsess_" + str(i)]:
            typeExsess = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "exsess>", dictExsess[i] ))
    
    if typeExsess:
        objeto = prefijo + "exsess>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
     
    if "1." in row["profleg"] or "2." in row["profleg"] or "3." in row["profleg"] or "4." in row["profleg"]:
        objeto = prefijo + "profleg>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["profleg"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "profleg>", '"Ningún otro trabajo en absoluto."' ))
            
        elif "2" in row["profleg"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "profleg>", '"Ningún otro puesto público."' ))
        
        elif "3" in row["profleg"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "profleg>", '"Sólo otros ciertos puesto públicos."' ))
            
        elif "4" in row["profleg"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "profleg>", '"Puestos privados/profesionales."' ))
     
    if "1" in row["assets"]:
        objeto = prefijo + "assets>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    typeIncome = False
    for i in range(1,9):
        if str(i) in row["income_" + str(i)]:
            typeIncome = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "income>", dictIncome[i] ))
    
    if typeIncome:
        objeto = prefijo + "income>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["pubmeet"] or "2" in row["pubmeet"]:
        objeto = prefijo + "pubmeet>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["pubmeet"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "pubmeet>", '"Publicas."' ))
            
        elif "2" in row["pubmeet"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "pubmeet>", '"Privadas."' ))
            
    if "1" in row["pubmin"]:
        objeto = prefijo + "pubmin>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
        
    if "1" in row["recvote"] or "2" in row["recvote"] or "3" in row["recvote"]:
        objeto = prefijo + "recvote>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["recvote"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "recvote>", '"Registro público."' ))
            
        elif "2" in row["recvote"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "recvote>", '"Secreto."' ))
            
        elif "3" in row["recvote"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "recvote>", '"Ambos (Depende del tema votado)."' ))
            
    
    if "1" in row["quorum"]:
        objeto = prefijo + "quorum>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["commit"]:
        objeto = prefijo + "commit>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## Judiciary
# ### Form and structure

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1." in row["levjud"] or "2." in row["levjud"] or "3." in row["levjud"] or "4." in row["levjud"]:
        objeto = prefijo + "levjud>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["levjud"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "levjud>", '"Sólo Suprema Corte o Corte Superior."' ))
            
        elif "2" in row["levjud"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "levjud>", '"Suprema Corte y otras cortes que se determinarán por la Ley."' ))
        
        elif "3" in row["levjud"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "levjud>", '"Suprema Corte y otras cortes específicas."' ))
            
        elif "4" in row["levjud"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "levjud>", '"Otras cortes mencionadas, pero no Suprema Corte."' ))
            
            
    for i in range(1,9):
        if str(i) in row["judcrts_" + str(i)]:
            objeto = prefijo + "judcrts" + str(i) + ">"
            datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
      
    if "1" in row["judind"]:
        objeto = prefijo + "judind>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["judprec"]:
        objeto = prefijo + "judprec>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Supreme Court

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["hocop"]:
        objeto = prefijo + "hocop>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Ordinary court

# %%
dictOrdres = {
    1 : '"Debe pertenecer a un partido en específico."',
    2 : '"Debe pertenecer un genero en específico."',
    3 : '"Debe ser miembro de una denominacion religiosa en específico."',
    4 : '"Debe tener una identidad lingüistica/nacional/racial específica."',
    5 : '"Debe ser ciudadano."',
    6 : '"Debe ser ciudadano nativo."',
    7 : '"Debe tener cierto nivel de educación."',
    8 : '"No debe ser transgresor de la ley."',
    9 : '"Debe ser un abogado."',
    10: '"Debe tener la nacionalidad del país."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if numberRegex.match(row["ordterm"]) != None and row["ordterm"] != "0" and row["ordterm"] != "99" and row["ordterm"] != "":
        objeto = prefijo + "ordterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if row["ordterm"] == "100":
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterm>", '"Sin Límite"' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterm>", '"' + row["ordterm"] + '"' ))
            
    
    if "1" in row["ordterml"] or "2" in row["ordterml"] or "3" in row["ordterml"] or "4" in row["ordterml"] or "5" in row["ordterml"]:
        objeto = prefijo + "ordterml>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["ordterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterml>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["ordterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterml>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["ordterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterml>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["ordterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterml>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["ordterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordterml>", '"Sin límite de periodos."' ))
            
    if "90." not in row["ordage"] and  "96." not in row["ordage"] and  "97." not in row["ordage"] and  "98." not in row["ordage"] and  "99." not in row["ordage"] and row["ordage"] != "nan":
        objeto = prefijo + "ordage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["ordage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordage>", '"Mayor de edad."' ))
            
        elif "16." in row["ordage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordage>", '"' + str(row["ordage"])[4:] + '"' ))
            
            
    typeOrdres = False
    for i in range(1,11):
        if str(i) in row["ordres_" + str(i)]:
            typeOrdres = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ordres>", dictOrdres[i] ))
    
    if typeOrdres:
        objeto = prefijo + "ordres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Administrative

# %%
dictAdres = {
    1 : '"Debe pertenecer a un partido en específico."',
    2 : '"Debe pertenecer un genero en específico."',
    3 : '"Membresía o posición de ministro en una denominación religiosa en específico."',
    4 : '"Debe tener una identidad lingüistica/nacional/racial específica."',
    5 : '"Debe ser ciudadano."',
    6 : '"Debe ser ciudadano nativo."',
    7 : '"Debe tener cierto nivel de educación."',
    8 : '"No debe ser transgresor de la ley."',
    9 : '"Debe ser un abogado."',
    10: '"Debe tener la nacionalidad del país."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if numberRegex.match(row["adterm"]) != None and row["adterm"] != "0" and row["adterm"] != "99" and row["adterm"] != "" and "99" not in row["adterm"]:
        objeto = prefijo + "adterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if row["adterm"] == "100":
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adterm>", '"Sin Límite"' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adterm>", '"' + row["adterm"] + '"' ))
            
    
    if "1" in row["adtermn"] or "2" in row["adtermn"] or "3" in row["adtermn"] or "4" in row["adtermn"] or "5" in row["adtermn"]:
        objeto = prefijo + "adtermn>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["adtermn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adtermn>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["adtermn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adtermn>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["adtermn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adtermn>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["adtermn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adtermn>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["adtermn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adtermn>", '"Sin límite de periodos."' ))
    
            
    if "90." not in row["adage"] and  "96." not in row["adage"] and  "97." not in row["adage"] and  "98." not in row["adage"] and  "99." not in row["adage"] and row["adage"] != "nan":
        objeto = prefijo + "adage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["adage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adage>", '"Mayor de edad."' ))
            
        elif "16." in row["adage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adage>", '"' + str(row["adage"])[4:] + '"' ))
            
    
    typeAdres = False
    for i in range(1,11):
        if str(i) in row["adres_" + str(i)]:
            typeAdres = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "adres>", dictAdres[i] ))

    if typeAdres:
        objeto = prefijo + "adres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["illadmin"]:
        objeto = prefijo + "illadmin>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Constitutional Court

# %%
dictConpow = {
    1 : '"Supervisar elecciones."',
    2 : '"Interpelación al poder Ejecutivo."',
    3 : '"Contrarrestar la corrupción."',
    4 : '"Constitucionalodad de los partidos políticos."',
    5 : '"Revisión de estados de emergencia."',
    6 : '"Revisión de tratados."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["conrem"]:
        objeto = prefijo + "conrem>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if numberRegex.match(row["conterm"]) != None and row["conterm"] != "0" and row["conterm"] != "99" and row["conterm"] != "" and "99" not in row["conterm"]:
        objeto = prefijo + "conterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if row["conterm"] == "100":
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conterm>", '"Sin Límite"' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conterm>", '"' + row["adterm"] + '"' ))
    
    if "1" in row["conlim"] or "2" in row["conlim"] or "3" in row["conlim"] or "4" in row["conlim"] or "5" in row["conlim"]:
        objeto = prefijo + "conlim>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["conlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conlim>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["conlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conlim>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["conlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conlim>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["conlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conlim>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["conlim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conlim>", '"Sin límite de periodos."' ))
            
    if "90." not in row["conage"] and  "96." not in row["conage"] and  "97." not in row["conage"] and  "98." not in row["conage"] and  "99." not in row["conage"] and row["conage"] != "nan":
        objeto = prefijo + "conage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["conage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conage>", '"Mayor de edad."' ))
            
        elif "16." in row["conage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conage>", '"' + str(row["conage"])[4:] + '"' ))
            
    
    typeConres = False
    for i in range(1,11):
        if str(i) in row["conres_" + str(i)]:
            typeConres = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conres>", dictAdres[i] ))

    if typeConres:
        objeto = prefijo + "conres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    typeConpow = False
    for i in range(1,7):
        if str(i) in row["conpow_" + str(i)]:
            typeConpow = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "conpow>", dictConpow[i] ))

    if typeConpow:
        objeto = prefijo + "conpow>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
     

    if "1" in row["concop"]:
        objeto = prefijo + "concop>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Judicial Review

# %%
dictInterp = {
    1 : '"Cualquier Corte Orninaria."',
    2 : '"Corte Constitucional/Consejo Constitucional."',
    3 : '"Sólo la Suprema Corte."',
    4 : '"Cámara especial de la Suprema Corte."',
    5 : '"Primera (o única) cámara de la Legislatura."',
    6 : '"Segunda cámara de la Legislatura."',
    7 : '"Ambas cámaras de la Legislatura en simultáneo."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    typeInterp= False
    for i in range(1,7):
        if str(i) in row["interp_" + str(i)]:
            typeInterp = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "interp>", dictInterp[i] ))

    if typeInterp:
        objeto = prefijo + "interp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["amparo"]:
        objeto = prefijo + "amparo>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Removal

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["jrem"]:
        objeto = prefijo + "jrem>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    
    if "1" in row["judsal"]:
        objeto = prefijo + "judsal>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["judretir"] or "2" in row["judretir"] or "3" in row["judretir"]:
        objeto = prefijo + "judretir>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["judretir"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "judretir>", '"Para jueces de la Corte Suprema."' ))
            
        elif "2" in row["judretir"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "judretir>", '"Para jueces de Cortes Ordinarias."' ))
        
        elif "3" in row["judretir"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "judretir>", '"Para la Corte Suprema y Cortes Ordinarias."' ))

# %% [markdown]
# ### Federalism

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["fedsep"] or "2" in row["fedsep"] or "3" in row["fedsep"]:
        objeto = prefijo + "fedsep>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["fedsep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "fedsep>", '"Las leyes del Gobierno Federal/Nacional son superiores."' ))
            
        elif "2" in row["fedsep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "fedsep>", '"Las leyes del Gobierno Sub Nacional son superiores."' ))
        
        elif "3" in row["fedsep"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "fedsep>", '"Depende el Tópico."' ))
            
    
    if "1" in row["fedrev"]:
        objeto = prefijo + "fedrev>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Secession and Accession

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["seccess"] or "2" in row["seccess"] or "3" in row["seccess"]:
        objeto = prefijo + "seccess>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["seccess"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "seccess>", '"Se permite sólo para unidades subsidiarias."' ))
            
        elif "2" in row["seccess"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "seccess>", '"Se permite, pero no se específica quién debe hacerlo."' ))
        
        elif "3" in row["seccess"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "seccess>", '"No se permite."' ))
            
            
    if "1" in row["access"]:
        objeto = prefijo + "access>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Autonomy of Indigenous Groups

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    for i in range(1, 7):
        if str(i) in row["indpolgr_" + str(i)]:
            objeto = prefijo + "indpolgr" + str(i) + ">"
            datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
            
    if "1" in row["indcit"]:
        objeto = prefijo + "indcit>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## Elections
# ### Political Parties

# %%
dictPartunco = {
    1 : '"Poder Ejecutivo."',
    2 : '"Poder Legislativo."',
    3 : '"Poder Judicial."',
    4 : '"Corte Constitucional."',
    5 : '"Comisión Central de Elecciones."',
    6 : '"Corte Electoral."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["partrght"]:
        objeto = prefijo + "partrght>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["partprf"] or "2" in row["partprf"] or "3" in row["partprf"]:
        objeto = prefijo + "partprf>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["partprf"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprf>", '"Todos los partidos."' ))
            
        elif "2" in row["partprf"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprf>", '"Sólo ciertos partidos."' ))
        
        elif "3" in row["partprf"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprf>", '"Sólo cierto tipo de partidos."' ))
            
    if "1" in row["partprh"] or "2" in row["partprh"] or "3" in row["partprh"]:
        objeto = prefijo + "partprh>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["partprh"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprh>", '"Todos los partidos."' ))
            
        elif "2" in row["partprh"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprh>", '"Sólo ciertos partidos."' ))
        
        elif "3" in row["partprh"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partprh>", '"Sólo cierto tipo de partidos."' ))
         
    typePartunco= False
    for i in range(1,7):
        if str(i) in row["partunco_" + str(i)]:
            typePartunco = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "partunco>", dictPartunco[i] ))

    if typePartunco:
        objeto = prefijo + "partunco>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Referenda and Initiatives

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["initiat"]:
        objeto = prefijo + "initiat>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["referen"]:
        objeto = prefijo + "referen>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Suffrage

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["voteres"]:
        objeto = prefijo + "voteres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["voteun"]:
        objeto = prefijo + "voteun>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Oversight

# %%
dictEcres = {
    1 : '"Debe pertenecer a un partido en específico."',
    2 : '"Debe pertenecer un genero en específico."',
    3 : '"Membresía o posición de ministro en una denominación religiosa en específico."',
    4 : '"Debe tener una identidad lingüistica/nacional/racial específica."',
    5 : '"Debe ser ciudadano."',
    6 : '"Debe ser ciudadano nativo."',
    7 : '"Debe tener cierto nivel de educación."',
    8 : '"No debe ser transgresor de la ley."',
    9 : '"Debe tener la nacionalidad del país."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if numberRegex.match(row["ecterm"]) != None and row["ecterm"] != "0" and row["ecterm"] != "99" and row["ecterm"] != "" and "99" not in row["ecterm"]:
        objeto = prefijo + "ecterm>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if row["ecterm"] == "100":
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterm>", '"Sin Límite"' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterm>", '"' + row["ecterm"] + '"' ))
            
    if "1" in row["ecterml"] or "2" in row["ecterml"] or "3" in row["ecterml"] or "4" in row["ecterml"] or "5" in row["ecterml"]:
        objeto = prefijo + "ecterml>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["ecterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterml>", '"Sólo 1 período permitido en total."' ))
            
        elif "2" in row["ecterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterml>", '"Sólo 2 períodos permitidos en total."' ))
        
        elif "3" in row["ecterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterml>", '"No se permiten periodos sucesivos, pero sí multiples períodos no sucesivos."' ))
            
        elif "4" in row["ecterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterml>", '"Sólo 2 períodos sucesivos permitidos, pero multiples periodos no sucesivos permitidos."' ))
            
        elif "5" in row["ecterml"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecterml>", '"Sin límite de periodos."' ))
            
    if "90." not in row["ecage"] and  "96." not in row["ecage"] and  "97." not in row["ecage"] and  "98." not in row["ecage"] and  "99." not in row["ecage"] and row["ecage"] != "nan":
        objeto = prefijo + "ecage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1." in row["ecage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecage>", '"Mayor de edad."' ))
            
        elif "16." in row["ecage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecage>", '"16 o menor."' ))
            
        else:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecage>", '"' + str(row["ecage"])[4:] + '"' ))
    
    typeEcres= False
    for i in range(1,7):
        if str(i) in row["ecres_" + str(i)]:
            typeEcres = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "ecres>", dictEcres[i] ))

    if typeEcres:
        objeto = prefijo + "ecres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Characteristics

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["compvote"]:
        objeto = prefijo + "compvote>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["freeelec"]:
        objeto = prefijo + "freeelec>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["electsch"] or "2" in row["electsch"] or "3" in row["electsch"]:
        objeto = prefijo + "electsch>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["electsch"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "electsch>", '"El día de elecciones es declarado feriado nacional."' ))
            
        elif "2" in row["electsch"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "electsch>", '"Las elecciones se celebran los fines de semana."' ))
        
        elif "3" in row["electsch"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "electsch>", '"Las elecciones se celebran durante la semana."' ))
            
          
    if "1" in row["camppubf"]:
        objeto = prefijo + "camppubf>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["census"]:
        objeto = prefijo + "census>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## Regulatory and Oversight Bodies

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    ### Ombudsman
    if "1" in row["ombuds"]:
        objeto = prefijo + "ombuds>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Cenrtal Bank
    if "1" in row["bank"]:
        objeto = prefijo + "bank>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
         
    ### Media
    if "1" in row["medcom"]:
        objeto = prefijo + "medcom>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Judicial Council
    if "1" in row["jc"]:
        objeto = prefijo + "jc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Corruption
    if "1" in row["cc"]:
        objeto = prefijo + "cc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["civil"]:
        objeto = prefijo + "civil>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Human Rights
    if "1" in row["hr"]:
        objeto = prefijo + "hr>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## international

# %%
dictWar = {
    1: '"El Jefe de Estado."',
    2: '"El Jefe de Gobierno."',
    3: '"El Gobierno/Gabinete."',
    4: '"La primera (o única) cámara de la Legislatura."',
    5: '"La segunda cámara de la Legislatura."',
    6: '"Cualquiera de las cámaras de la Legislatura."',
    7: '"Ambas cámaras de la Legislatura, en conjunto."',
    8: '"El consejo nacional de seguridad o su equivalente."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    ### General
    if "1" in row["intlaw"]:
        objeto = prefijo + "intlaw>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))     
    
    if "1" in row["custlaw"]:
        objeto = prefijo + "custlaw>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["intorgs"]:
        objeto = prefijo + "intorgs>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### War and Foreign Policy
    if "1" in row["headforn"] or "2" in row["headforn"] or "3" in row["headforn"] or "4" in row["headforn"]:
        objeto = prefijo + "headforn>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["headforn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "headforn>", '"Jefe de Estado."' ))
            
        elif "2" in row["headforn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "headforn>", '"Jefe de Gobierno."' ))
        
        elif "3" in row["headforn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "headforn>", '"El Gobierno/Gabinete."' ))
            
        elif "4" in row["headforn"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "headforn>", '"Ministro de Relaciones Exteriores."' ))
            
    
    typeWar= False
    for i in range(1,9):
        if str(i) in row["war_" + str(i)]:
            typeWar = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "war>", dictWar[i] ))

    if typeWar:
        objeto = prefijo + "war>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    ### Treaties
    if "1" in row["treat"]:
        objeto = prefijo + "treat>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Duties

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    ### State
    if "1" in row["provwork"]:
        objeto = prefijo + "provwork>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["cultrght"]:
        objeto = prefijo + "cultrght>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
       
    ### Citizens
    if "1" in row["taxes"]:
        objeto = prefijo + "taxes>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["milserv"]:
        objeto = prefijo + "milserv>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["work"]:
        objeto = prefijo + "work>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["prtyduty"]:
        objeto = prefijo + "prtyduty>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## Criminal Procedures

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    if "1" in row["jury"]:
        objeto = prefijo + "jury>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["vicright"]:
        objeto = prefijo + "vicright>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["excrim"] or "2" in row["excrim"] or "3" in row["excrim"]:
        objeto = prefijo + "excrim>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["excrim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "excrim>", '"Permitido específicamente."' ))
            
        elif "2" in row["excrim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "excrim>", '"Prohibido específicamente."' ))
            
        elif "3" in row["excrim"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "excrim>", '"Condicional al estado de la persona, el tipo de crimen u otras circunstancias."' ))
            
    if "1" in row["evidence"]:
        objeto = prefijo + "evidence>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["prerel"]:
        objeto = prefijo + "prerel>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["habcorp"]:
        objeto = prefijo + "habcorp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto )) 
        
    if "1" in row["wolaw"]:
        objeto = prefijo + "wolaw>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto )) 
            
    if "1" in row["prisonrg"]:
        objeto = prefijo + "prisonrg>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto )) 
        
    if "1" in row["cappun"] or "2" in row["cappun"]:
        objeto = prefijo + "cappun>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["cappun"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "cappun>", '"Universalmente Prohibido."' ))
            
        elif "2" in row["cappun"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "cappun>", '"Permitido sólo en caso de guerra."' ))
            
            
    if "1" in row["corppun"] or "2" in row["corppun"]:
        objeto = prefijo + "corppun>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["corppun"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "corppun>", '"Universalmente Prohibido."' ))
            
        elif "2" in row["corppun"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "corppun>", '"Permitido sólo en caso de guerra."' ))
      
    
    if "1" in row["dueproc"]:
        objeto = prefijo + "dueproc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["examwit"] or "2" in row["examwit"] or "3" in row["examwit"]:
        objeto = prefijo + "examwit>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["examwit"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "examwit>", '"Sólo la evidencia."' ))
            
        elif "2" in row["examwit"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "examwit>", '"Sólo interrogar testigos."' ))
            
        elif "3" in row["examwit"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "examwit>", '"Revisar evidencia e interrogar testigos."' ))
            
    
    if "1" in row["expost"]:
        objeto = prefijo + "expost>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["falseimp"]:
        objeto = prefijo + "falseimp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["fairtri"]:
        objeto = prefijo + "fairtri>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["speedtri"]:
        objeto = prefijo + "speedtri>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        
    if "1" in row["pubtri"]:
        objeto = prefijo + "pubtri>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))   
        
        
    if "1" in row["presinoc"]:
        objeto = prefijo + "presinoc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto )) 
        
    
    if "1" in row["trilang"]:
        objeto = prefijo + "trilang>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["juvenile"]:
        objeto = prefijo + "juvenile>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["doubjep"]:
        objeto = prefijo + "doubjep>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["miranda"]:
        objeto = prefijo + "miranda>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["couns"]:
        objeto = prefijo + "couns>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    ### Debt
    if "1" in row["debtors"]:
        objeto = prefijo + "debtors>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ## Rights

# %%
dictCitrev = {
    1 : '"Al adquirir la nacionalidad en otro país."',
    2 : '"Al ser condenado por un crimen."',
    3 : '"Al ser empleado o integrante de una comisión de otro gobierno."'
}

dictRightres = {
    1 : '"Propietarios."',
    2 : '"Minoría Racial/Étnica/Religiosa/Lingüistica/Nacional."',
    3 : '"Mujeres."',
    4 : '"No propietarios."',
    5 : '"Campesinos."',
    6 : '"Inmigrantes."',
    7 : '"Adultos mayores."',
    8 : '"Discapacitados."'
}

dictRellaw = {
    1 : '"Se aplica la ley tradicional si no aplica ningúna otra ley."',
    2 : '"Usada como como fuente para para la ley secular."',
    3 : '"Base, fuente principal, superior o fuente suprema de la ley secular."'
}

dictIntprop = {
    1 : '"Patentes."',
    2 : '"Derechos de autor."',
    3 : '"Marcas Comerciales"',
    4 : '"Referencia general a la propiedad intelectual."'
}

dictIntrght = {
    1 : '"ONU Declaración Universal de Derechos Humanos (1948)."',
    2 : '"Declaración de Derechos de Francia (1789)."',
    3 : '"Art. 45, Carta ONU (1945)."',
    4 : '"Convenio Europeo para la Protección de los Derechos Humanos y las Libertades Fundamentales (1950)."',
    5 : '"Pacto Internacional de Derechos Civiles y Políticos (1966)."',
    6 : '"Pacto Internacional de Derechos Económicos y Sociales (1966)."',
    7 : '"Convención Americana sobre Derechos Humanos (1969)."',
    8 : '"Acuerdos de Helsinki (1966)."',
    9 : '"Carta Africana sobre los Derechos de los Pueblos Humanos (1981)."'
}

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    ### Citizenship
    if "1" in row["natcit"]:
        objeto = prefijo + "natcit>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    typeCitrev = False
    for i in range(1,4):
        if str(i) in row["citrev_" + str(i)]:
            typeCitrev = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "citrev>", dictCitrev[i] ))
            
    if typeCitrev:
        objeto = prefijo + "citrev>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["citren"]:
        objeto = prefijo + "citren>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["citdep"]:
        objeto = prefijo + "citdep>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["resenex"] or "2" in row["resenex"] or "3" in row["resenex"]:
        objeto = prefijo + "resenex>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["resenex"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "resenex>", '"Sólo restricciones de entrada."' ))
            
        elif "2" in row["resenex"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "resenex>", '"Sólo restricciones de salida."' ))
            
        elif "3" in row["resenex"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "resenex>", '"Restricciones de entrada y salida."' ))
            
    ### Rule of Law Principles
    if "1" in row["equal"]:
        objeto = prefijo + "equal>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    for i in range(1,17):
        if str(i) in row["equalgr_" + str(i)]:
            objeto = prefijo + "equalgr" + str(i) + ">"
            datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    typeRightres = False
    for i in range(1,9):
        if str(i) in row["rightres_" + str(i)]:
            typeRightres = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "rightres>", dictRightres[i] ))
            
    if typeRightres:
        objeto = prefijo + "rightres>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["binding"]:
        objeto = prefijo + "binding>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Information
    if "1" in row["infoacc"]:
        objeto = prefijo + "infoacc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["libel"]:
        objeto = prefijo + "libel>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Religion
    if "1" in row["offrel"] or "2" in row["offrel"]:
        objeto = prefijo + "offrel>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["offrel"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "offrel>", '"Religión nacional específicada."' ))
            
        elif "2" in row["offrel"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "offrel>", '"Ciertas Religiones disfrutan de tratamiento especial."' ))
            
            
    if "1" in row["freerel"]:
        objeto = prefijo + "freerel>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    typeRellaw = False
    for i in range(1,4):
        if str(i) in row["rellaw_" + str(i)]:
            typeRellaw = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "rellaw>", dictRellaw[i] ))
            
    if typeRellaw:
        objeto = prefijo + "rellaw>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["seprel"]:
        objeto = prefijo + "seprel>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["reltax"]:
        objeto = prefijo + "reltax>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Economic Rights
    if "1" in row["exprop"]:
        objeto = prefijo + "exprop>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["remuner"]:
        objeto = prefijo + "remuner>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["jointrde"]:
        objeto = prefijo + "jointrde>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["strike"] or "2" in row["strike"]:
        objeto = prefijo + "strike>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["strike"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "strike>", '"Sin limitaciones."' ))
            
        elif "2" in row["strike"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "strike>", '"Con limitaciones."' ))
            
    if "1" in row["leisure"]:
        objeto = prefijo + "leisure>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["standliv"]:
        objeto = prefijo + "standliv>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["transfer"]:
        objeto = prefijo + "transfer>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    typeIntprop = False
    for i in range(1,5):
        if str(i) in row["intprop_" + str(i)]:
            typeIntprop = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "intprop>", dictIntprop[i] ))
            
    if typeIntprop:
        objeto = prefijo + "intprop>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["busines"]:
        objeto = prefijo + "busines>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["conright"]:
        objeto = prefijo + "conright>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    for i in range(1,5):
        if str(i) in row["finsup_" + str(i)]:
            objeto = prefijo + "finsup" + str(i) + ">"
            datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
            
    if "1" in row["proprght"]:
        objeto = prefijo + "proprght>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["freecomp"]:
        objeto = prefijo + "freecomp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["scifree"]:
        objeto = prefijo + "scifree>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["occupate"]:
        objeto = prefijo + "occupate>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    
    if "1" in row["safework"] or "3" in row["safework"]:
        objeto = prefijo + "safework>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
            
        if "3" in row["safework"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "safework>", '"El estado debe proveer condiciones de trabajo seguras."' ))
            
    if "1" in row["childwrk"]:
        objeto = prefijo + "childwrk>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["shelter"]:
        objeto = prefijo + "shelter>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Social and Family
    if "1" in row["marriage"] or "2" in row["marriage"]:
        objeto = prefijo + "marriage>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["marriage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "marriage>", '"Matrimonio en general."' ))
            
        elif "2" in row["marriage"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "marriage>", '"Sólo entre un hombre y una mujer."' ))
    
    if "1" in row["fndfam"]:
        objeto = prefijo + "fndfam>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["matequal"]:
        objeto = prefijo + "matequal>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
    
    if "1" in row["childpro"]:
        objeto = prefijo + "childpro>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["civmar"]:
        objeto = prefijo + "civmar>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["selfdet"]:
        objeto = prefijo + "selfdet>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Civil and Political
    if "1" in row["life"]:
        objeto = prefijo + "life>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["slave"] or "2" in row["slave"] or "3" in row["slave"]:
        objeto = prefijo + "slave>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["slave"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "slave>", '"Prohibido Universalmente."' ))
            
        elif "2" in row["slave"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "slave>", '"Prohibido excepto en caso de guerra."' ))
            
        elif "3" in row["slave"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "slave>", '"Prohibido con excepciones específicas."' ))
       
    
    if "1" in row["torture"] or "2" in row["torture"] or "3" in row["torture"]:
        objeto = prefijo + "torture>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["torture"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "torture>", '"Prohibido Universalmente."' ))
            
        elif "2" in row["torture"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "torture>", '"Prohibido excepto en caso de guerra."' ))
            
        elif "3" in row["torture"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "torture>", '"Prohibido con el propósito de extraer confesiones."' ))
       
    if "1" in row["cruelty"] or "2" in row["cruelty"]:
        objeto = prefijo + "cruelty>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["cruelty"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "cruelty>", '"Prohibido Universalmente."' ))
            
        elif "2" in row["cruelty"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "cruelty>", '"Prohibido excepto en caso de guerra."' ))
            
            
    if "1" in row["privacy"]:
        objeto = prefijo + "privacy>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["freemove"]:
        objeto = prefijo + "freemove>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["opinion"]:
        objeto = prefijo + "opinion>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["express"]:
        objeto = prefijo + "express>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["petition"]:
        objeto = prefijo + "petition>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["press"]:
        objeto = prefijo + "press>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    typeIntrght= False
    for i in range(1,4):
        if str(i) in row["intrght_" + str(i)]:
            typeIntrght = True
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "intrght>", dictIntrght[i] ))
            
    if typeIntrght:
        objeto = prefijo + "intrght>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["assem"]:
        objeto = prefijo + "assem>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["assoc"]:
        objeto = prefijo + "assoc>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["inalrght"]:
        objeto = prefijo + "inalrght>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["devlpers"]:
        objeto = prefijo + "devlpers>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["nomil"]:
        objeto = prefijo + "nomil>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
     
    if "1" in row["asylum"]:
        objeto = prefijo + "asylum>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["arms"]:
        objeto = prefijo + "arms>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))

# %% [markdown]
# ### Special Issue Domains

# %%
for index, row in dfFiltered.iterrows():
    sujeto = dictEventos[str(row["evntid"])]
    
    ### Environment
    if "1" in row["env"]:
        objeto = prefijo + "env>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["resrce"]:
        objeto = prefijo + "resrce>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Art and Sciences
    if "1" in row["artists"]:
        objeto = prefijo + "artists>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["science"]:
        objeto = prefijo + "science>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Media and Communications
    if "1" in row["telecom"]:
        objeto = prefijo + "telecom>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["radio"]:
        objeto = prefijo + "radio>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["tv"]:
        objeto = prefijo + "tv>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
     
    if "1" in row["govmed"] or "2" in row["govmed"] or "3" in row["govmed"]:
        objeto = prefijo + "govmed>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["govmed"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "govmed>", '"El estado tiene control de todos los medios de comunicación."' ))
            
        elif "2" in row["govmed"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "govmed>", '"El estado opera algunos medios de comunicación."' ))
            
        elif "3" in row["govmed"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "govmed>", '"El estado no puede operar ningún medio de comunicación."' ))
            
    ### Military
    if "1" in row["comchief"] or "2" in row["comchief"]:
        objeto = prefijo + "comchief>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["comchief"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "comchief>", '"Jefe de Estado."' ))
            
        elif "2" in row["comchief"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "comchief>", '"Jefe de Gobierno."' ))
            
    if "1" in row["terror"]:
        objeto = prefijo + "terror>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Economic Legislation
    if "1" in row["econplan"]:
        objeto = prefijo + "econplan>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    ### Race, Ethnicity, and Language
    if "1" in row["ethincl"]:
        objeto = prefijo + "ethincl>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["opgroup"]:
        objeto = prefijo + "opgroup>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["lang"] or "2" in row["lang"] or "3" in row["lang"] or "4" in row["lang"]:
        objeto = prefijo + "lang>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["lang"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lang>", '"Sólo establece el idioma oficial."' ))
            
        elif "2" in row["lang"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lang>", '"Sólo establece el idioma nacional."' ))
            
        elif "3" in row["lang"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lang>", '"Establece el idioma oficial y el idioma nacional."' ))
            
        elif "4" in row["lang"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "lang>", '"No establece idioma, pero específica el lenguaje para negocios gubernamentales."' ))
            
    if "1" in row["langprot"] or "3" in row["langprot"]:
        objeto = prefijo + "langprot>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
            
        if "3" in row["langprot"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "langprot>", '"La Constitución exige explícitamente la neutralidad hacia las lenguas."' ))
            
    ### Education        
    if "1" in row["edcomp"]:
        objeto = prefijo + "edcomp>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["edfree"]:
        objeto = prefijo + "edfree>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["acfree"]:
        objeto = prefijo + "acfree>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
    if "1" in row["achighed"] or "2" in row["achighed"]:
        objeto = prefijo + "achighed>"
        datos.write(formato.format(sujeto, clasesDatos['type'], objeto ))
        
        if "1" in row["achighed"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "achighed>", '"Para todos por igual."' ))
            
        elif "2" in row["achighed"]:
            datos.write(formato.format(sujeto, clasesDatos['detalle'] + "achighed>", '"Limitado según algún método de calificación."' ))

# %%
datos.close()

# %%
setVerificacion = set()
datos = open("Ttl/datosDuros.ttl", "r")

listRepetidos = []

contador = 0
for i in datos:
    if i in setVerificacion:
        listRepetidos.append(i)
    setVerificacion.add(i)
    contador += 1

# %%
contador
# Out:
# 457844

# %%
len(setVerificacion)
# Out:
# 457844

# %%
setVerificacion = set()
datos = open("Ttl/EventosExtra.ttl", "r")

listRepetidos = []

contador = 0
for i in datos:
    if i in setVerificacion:
        listRepetidos.append(i)
    setVerificacion.add(i)
    contador += 1

# %%
contador
# Out:
# 420

# %%
len(setVerificacion)
# Out:
# 420
